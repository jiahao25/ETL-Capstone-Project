# %% [markdown]
# ### Capstone - Parsing Data (Part 1)

# %% [markdown]
# In this demonstration, i will parse the relevant data into the application that the Capstone team has built.

# %% [markdown]
# The aim of the Capstone project is to create a Chinese stroke-based keyboard for the patients to use. The keyboard needs to be able to serve 2 functions.
#
# 1. Predict chinese characters when the relevant strokes are being typed.
# 2. Predict chinese phrases (>= 2 chinese characters) whenever a Chinese character is being selected.
#
# This section will demonstrate the 1st function.

# %%
import pandas as pd
import json

# %% [markdown]
# Open character frequency data.

# %%
df = pd.read_csv('cleaned_data.csv')
df
# Out:
#       Index  Absolute Count  Frequency/Million words
# 0         的         4650143               45845.3460
# 1         我         2841511               28014.2040
# 2         了         2725964               26875.0365
# 3         不         1752436               17277.1106
# 4         是         1648662               16254.0119
# 5         你         1622660               15997.6605
# 6         一         1356666               13375.2493
# 7         在          992131                9781.3312
# 8         有          906700                8939.0746
# 9         个          856510                8444.2559
# 10        就          729449                7191.5728
# 11        人          651396                6422.0552
# 12        要          631789                6228.7515
# 13        好          628627                6197.5776
# 14        都          609802                6011.9836
# 15        也          504107                4969.9460
# 16        和          491847                4849.0758
# 17        想          478573                4718.2086
# 18        还          444030                4377.6523
# 19        啊          437670                4314.9496
# 20        吧          434052                4279.2800
# 21        这          399287                3936.5350
# 22        很          366334                3611.6543
# 23        会          364561                3594.1745
# 24        来          343989                3391.3569
# 25        年          330500                3258.3701
# 26        能          326366                3217.6133
# 27        去          321992                3174.4905
# 28        微          317055                3125.8170
# 29        博          312359                3079.5196
# ...     ...             ...                      ...
# 21176   汽油味              19                   0.1873
# 21177  东施效颦              19                   0.1873
# 21178    烧包              19                   0.1873
# 21179    树人              19                   0.1873
# 21180    译本              19                   0.1873
# 21181    无伦              19                   0.1873
# 21182  秦皇岛市              19                   0.1873
# 21183  星罗棋布              19                   0.1873
# 21184    多分              19                   0.1873
# 21185   退休证              19                   0.1873
# 21186    家闲              19                   0.1873
# 21187  巴洛克式              19                   0.1873
# 21188   玄关处              19                   0.1873
# 21189    都俾              19                   0.1873
# 21190     御              19                   0.1873
# 21191    怕事              19                   0.1873
# 21192   何星座              19                   0.1873
# 21193   韩范儿              19                   0.1873
# 21194    修为              19                   0.1873
# 21195    头筹              19                   0.1873
# 21196    芬芬              19                   0.1873
# 21197    玩死              19                   0.1873
# 21198    泅渡              19                   0.1873
# 21199    让她              19                   0.1873
# 21200    阿伤              19                   0.1873
# 21201   伤心处              19                   0.1873
# 21202    安尚              19                   0.1873
# 21203   火浇油              19                   0.1873
# 21204   阿米巴              19                   0.1873
# 21205    合水              19                   0.1873
#
# [21206 rows x 3 columns]

# %% [markdown]
# #### Step 1: Getting onegrams(single characters) from dataframe

# %%
onegram_df = df[df['Index'].map(len) == 1]
onegram_df
# Out:
#       Index  Absolute Count  Frequency/Million words
# 0         的         4650143               45845.3460
# 1         我         2841511               28014.2040
# 2         了         2725964               26875.0365
# 3         不         1752436               17277.1106
# 4         是         1648662               16254.0119
# 5         你         1622660               15997.6605
# 6         一         1356666               13375.2493
# 7         在          992131                9781.3312
# 8         有          906700                8939.0746
# 9         个          856510                8444.2559
# 10        就          729449                7191.5728
# 11        人          651396                6422.0552
# 12        要          631789                6228.7515
# 13        好          628627                6197.5776
# 14        都          609802                6011.9836
# 15        也          504107                4969.9460
# 16        和          491847                4849.0758
# 17        想          478573                4718.2086
# 18        还          444030                4377.6523
# 19        啊          437670                4314.9496
# 20        吧          434052                4279.2800
# 21        这          399287                3936.5350
# 22        很          366334                3611.6543
# 23        会          364561                3594.1745
# 24        来          343989                3391.3569
# 25        年          330500                3258.3701
# 26        能          326366                3217.6133
# 27        去          321992                3174.4905
# 28        微          317055                3125.8170
# 29        博          312359                3079.5196
# ...     ...             ...                      ...
# 19526     嬲              79                   0.7789
# 19566     怨              79                   0.7789
# 19607     儒              79                   0.7789
# 19627     检              79                   0.7789
# 19768     趋              78                   0.7690
# 19813     葛              78                   0.7690
# 19888     泥              78                   0.7690
# 19961     霖              59                   0.5817
# 19973     婷              59                   0.5817
# 20022     智              59                   0.5817
# 20041     扮              59                   0.5817
# 20160     壹              59                   0.5817
# 20174     舔              59                   0.5817
# 20177     啧              59                   0.5817
# 20190     岗              59                   0.5817
# 20252     唛              59                   0.5817
# 20297     硫              59                   0.5817
# 20349     禅              58                   0.5718
# 20359     堤              58                   0.5718
# 20375     俊              39                   0.3845
# 20418     瞓              39                   0.3845
# 20437     叉              39                   0.3845
# 20468     艺              39                   0.3845
# 20587     磕              39                   0.3845
# 20642     扶              39                   0.3845
# 20675     卧              39                   0.3845
# 20884     楽              19                   0.1873
# 20963     荐              19                   0.1873
# 21017     珍              19                   0.1873
# 21190     御              19                   0.1873
#
# [1943 rows x 3 columns]

# %% [markdown]
# #### Step 2: Make a character stroke dataframe

# %%
stroke = pd.read_csv('character_strokes.txt',sep='\t',header=None,names=['index','character','num_stroke','stroke_order','code'])

# %%
stroke.head(5)
# Out:
#    index character  num_stroke stroke_order  code
# 0      1         一           1            1   300
# 1     11         二           2           11   300
# 2     55         三           3          111   300
# 3    153         亖           4         1111   300
# 4    688         弎           6       111154   300

# %%
stroke.drop(columns=['index','code'],inplace=True)

# %% [markdown]
# #### Step 3: Combine stroke dataframe and character frequency dataframe, only keeping characters existing in both dataframes

# %%
onegram_df = onegram_df.merge(stroke,how='inner',left_on='Index',right_on='character')

# %%
onegram_df.drop(columns=['character'],inplace=True)

# %%
onegram_df
# Out:
#      Index  Absolute Count  Frequency/Million words  num_stroke  \
# 0        的         4650143               45845.3460           8
# 1        我         2841511               28014.2040           7
# 2        了         2725964               26875.0365           2
# 3        不         1752436               17277.1106           4
# 4        是         1648662               16254.0119           9
# 5        你         1622660               15997.6605           7
# 6        一         1356666               13375.2493           1
# 7        在          992131                9781.3312           6
# 8        有          906700                8939.0746           6
# 9        个          856510                8444.2559           3
# 10       就          729449                7191.5728          12
# 11       人          651396                6422.0552           2
# 12       要          631789                6228.7515           9
# 13       好          628627                6197.5776           6
# 14       都          609802                6011.9836          10
# 15       也          504107                4969.9460           3
# 16       和          491847                4849.0758           8
# 17       想          478573                4718.2086          13
# 18       还          444030                4377.6523           7
# 19       啊          437670                4314.9496          10
# 20       吧          434052                4279.2800           7
# 21       这          399287                3936.5350           7
# 22       很          366334                3611.6543           9
# 23       会          364561                3594.1745           6
# 24       来          343989                3391.3569           7
# 25       年          330500                3258.3701           6
# 26       能          326366                3217.6133          10
# 27       去          321992                3174.4905           5
# 28       微          317055                3125.8170          13
# 29       博          312359                3079.5196          12
# ...    ...             ...                      ...         ...
# 1913     嬲              79                   0.7789          17
# 1914     怨              79                   0.7789           9
# 1915     儒              79                   0.7789          16
# 1916     检              79                   0.7789          11
# 1917     趋              78                   0.7690          12
# 1918     葛              78                   0.7690          12
# 1919     泥              78                   0.7690           8
# 1920     霖              59                   0.5817          16
# 1921     婷              59                   0.5817          12
# 1922     智              59                   0.5817          12
# 1923     扮              59                   0.5817           7
# 1924     壹              59                   0.5817          12
# 1925     舔              59                   0.5817          14
# 1926     啧              59                   0.5817          11
# 1927     岗              59                   0.5817           7
# 1928     唛              59                   0.5817          10
# 1929     硫              59                   0.5817          12
# 1930     禅              58                   0.5718          12
# 1931     堤              58                   0.5718          12
# 1932     俊              39                   0.3845           9
# 1933     瞓              39                   0.3845          15
# 1934     叉              39                   0.3845           3
# 1935     艺              39                   0.3845           4
# 1936     磕              39                   0.3845          15
# 1937     扶              39                   0.3845           7
# 1938     卧              39                   0.3845           8
# 1939     楽              19                   0.1873          13
# 1940     荐              19                   0.1873           9
# 1941     珍              19                   0.1873           9
# 1942     御              19                   0.1873          12
#
#            stroke_order
# 0              32511354
# 1               3121534
# 2                    52
# 3                  1324
# 4             251112134
# 5               3235234
# 6                     1
# 7                132121
# 8                132511
# 9                   342
# 10         412512341354
# 11                   34
# 12            125221531
# 13               531521
# 14           1213251152
# 15                  525
# 16             31234251
# 17        1234251114544
# 18              1324454
# 19           2515212512
# 20              2515215
# 21              4134454
# 22            332511534
# 23               341154
# 24              1431234
# 25               311212
# 26           5425113535
# 27                12154
# 28        3322521353134
# 29         121251124124
# ...                 ...
# 1913  25121535312512153
# 1914          354554544
# 1915   3214524444132522
# 1916        12343414431
# 1917       121213435511
# 1918       122251135345
# 1919           44151335
# 1920   1452444412341234
# 1921       531412514512
# 1922       311342512511
# 1923            1213453
# 1924       121451251431
# 1925     31225111342444
# 1926        25111212534
# 1927            2522534
# 1928         2511121354
# 1929       132514154325
# 1930       452443251112
# 1931       121251112134
# 1932          325434354
# 1933    251114111251322
# 1934                544
# 1935               1225
# 1936    132511215425221
# 1937            1211134
# 1938           12512524
# 1939      3251141341234
# 1940          122132521
# 1941          112134333
# 1942       332311212152
#
# [1943 rows x 5 columns]

# %% [markdown]
# There is the same number of rows (1943), which means the one-grams in the stroke frequency dataset is a subset of the stroke order dataset.
#
# Great. Now we have a dataframe consisting of single character information. When the user types in strokes, it retrieves stroke information from the 'stroke_order' column. Then, using a ranking prediction algorith using metrics such as character frequencies, it can determine the most commonly used characters from the same stroke order.

# %% [markdown]
# #### Step 4: Parse the data into a JSON file (Hashmap) called onegram, with index as the character.

# %%
onegram_df = onegram_df.set_index('Index')

# %%
onegram_df.head(5)
# Out:
#        Absolute Count  Frequency/Million words  num_stroke stroke_order
# Index
# 的             4650143               45845.3460           8     32511354
# 我             2841511               28014.2040           7      3121534
# 了             2725964               26875.0365           2           52
# 不             1752436               17277.1106           4         1324
# 是             1648662               16254.0119           9    251112134

# %%
onegram_df.to_json('onegram.json',orient='index')
