# %% [markdown]
# ### Capstone - Parsing Data (Part 2)

# %% [markdown]
# The aim of the Capstone project is to create a Chinese stroke-based keyboard for the patients to use. The keyboard needs to be able to serve 2 functions.
#
# 1. Predict chinese characters when the relevant strokes are being typed.
# 2. Predict chinese phrases (>= 2 chinese characters) whenever a Chinese character is being selected.
#
# This section will demonstrate the 2nd function.

# %%
import pandas as pd

# %% [markdown]
# Open character frequency data

# %%
df = pd.read_csv('cleaned_data.csv')
df
# Out:
#       Index  Absolute Count  Frequency/Million words
# 0         的         4650143               45845.3460
# 1         我         2841511               28014.2040
# 2         了         2725964               26875.0365
# 3         不         1752436               17277.1106
# 4         是         1648662               16254.0119
# 5         你         1622660               15997.6605
# 6         一         1356666               13375.2493
# 7         在          992131                9781.3312
# 8         有          906700                8939.0746
# 9         个          856510                8444.2559
# 10        就          729449                7191.5728
# 11        人          651396                6422.0552
# 12        要          631789                6228.7515
# 13        好          628627                6197.5776
# 14        都          609802                6011.9836
# 15        也          504107                4969.9460
# 16        和          491847                4849.0758
# 17        想          478573                4718.2086
# 18        还          444030                4377.6523
# 19        啊          437670                4314.9496
# 20        吧          434052                4279.2800
# 21        这          399287                3936.5350
# 22        很          366334                3611.6543
# 23        会          364561                3594.1745
# 24        来          343989                3391.3569
# 25        年          330500                3258.3701
# 26        能          326366                3217.6133
# 27        去          321992                3174.4905
# 28        微          317055                3125.8170
# 29        博          312359                3079.5196
# ...     ...             ...                      ...
# 21176   汽油味              19                   0.1873
# 21177  东施效颦              19                   0.1873
# 21178    烧包              19                   0.1873
# 21179    树人              19                   0.1873
# 21180    译本              19                   0.1873
# 21181    无伦              19                   0.1873
# 21182  秦皇岛市              19                   0.1873
# 21183  星罗棋布              19                   0.1873
# 21184    多分              19                   0.1873
# 21185   退休证              19                   0.1873
# 21186    家闲              19                   0.1873
# 21187  巴洛克式              19                   0.1873
# 21188   玄关处              19                   0.1873
# 21189    都俾              19                   0.1873
# 21190     御              19                   0.1873
# 21191    怕事              19                   0.1873
# 21192   何星座              19                   0.1873
# 21193   韩范儿              19                   0.1873
# 21194    修为              19                   0.1873
# 21195    头筹              19                   0.1873
# 21196    芬芬              19                   0.1873
# 21197    玩死              19                   0.1873
# 21198    泅渡              19                   0.1873
# 21199    让她              19                   0.1873
# 21200    阿伤              19                   0.1873
# 21201   伤心处              19                   0.1873
# 21202    安尚              19                   0.1873
# 21203   火浇油              19                   0.1873
# 21204   阿米巴              19                   0.1873
# 21205    合水              19                   0.1873
#
# [21206 rows x 3 columns]

# %% [markdown]
# #### Step 1: Split dataframe into single characters (onegram) and multiple characters (multigram)

# %%
onegram_df = df[df['Index'].map(len) == 1]
onegram_df
# Out:
#       Index  Absolute Count  Frequency/Million words
# 0         的         4650143               45845.3460
# 1         我         2841511               28014.2040
# 2         了         2725964               26875.0365
# 3         不         1752436               17277.1106
# 4         是         1648662               16254.0119
# 5         你         1622660               15997.6605
# 6         一         1356666               13375.2493
# 7         在          992131                9781.3312
# 8         有          906700                8939.0746
# 9         个          856510                8444.2559
# 10        就          729449                7191.5728
# 11        人          651396                6422.0552
# 12        要          631789                6228.7515
# 13        好          628627                6197.5776
# 14        都          609802                6011.9836
# 15        也          504107                4969.9460
# 16        和          491847                4849.0758
# 17        想          478573                4718.2086
# 18        还          444030                4377.6523
# 19        啊          437670                4314.9496
# 20        吧          434052                4279.2800
# 21        这          399287                3936.5350
# 22        很          366334                3611.6543
# 23        会          364561                3594.1745
# 24        来          343989                3391.3569
# 25        年          330500                3258.3701
# 26        能          326366                3217.6133
# 27        去          321992                3174.4905
# 28        微          317055                3125.8170
# 29        博          312359                3079.5196
# ...     ...             ...                      ...
# 19526     嬲              79                   0.7789
# 19566     怨              79                   0.7789
# 19607     儒              79                   0.7789
# 19627     检              79                   0.7789
# 19768     趋              78                   0.7690
# 19813     葛              78                   0.7690
# 19888     泥              78                   0.7690
# 19961     霖              59                   0.5817
# 19973     婷              59                   0.5817
# 20022     智              59                   0.5817
# 20041     扮              59                   0.5817
# 20160     壹              59                   0.5817
# 20174     舔              59                   0.5817
# 20177     啧              59                   0.5817
# 20190     岗              59                   0.5817
# 20252     唛              59                   0.5817
# 20297     硫              59                   0.5817
# 20349     禅              58                   0.5718
# 20359     堤              58                   0.5718
# 20375     俊              39                   0.3845
# 20418     瞓              39                   0.3845
# 20437     叉              39                   0.3845
# 20468     艺              39                   0.3845
# 20587     磕              39                   0.3845
# 20642     扶              39                   0.3845
# 20675     卧              39                   0.3845
# 20884     楽              19                   0.1873
# 20963     荐              19                   0.1873
# 21017     珍              19                   0.1873
# 21190     御              19                   0.1873
#
# [1943 rows x 3 columns]

# %% [markdown]
# We don't need the character frequency of the one-gram dataframe.

# %%
onegram_df.drop(columns=['Absolute Count','Frequency/Million words'],inplace=True)
# Out:
# C:\Users\Lenovo\Anaconda3\lib\site-packages\pandas\core\frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
onegram_df.head(5)
# Out:
#   Index
# 0     的
# 1     我
# 2     了
# 3     不
# 4     是

# %%
multigram_df = df[df['Index'].map(len) > 1]
multigram_df
# Out:
#       Index  Absolute Count  Frequency/Million words
# 34       自己          290637                2865.3643
# 49       分享          222292                2191.5570
# 51       我们          213466                2104.5423
# 52       今天          206840                2039.2172
# 53       一下          202261                1994.0732
# 54       什么          202206                1993.5310
# 59       获得          193248                1905.2148
# 64       没有          179864                1773.2632
# 66       可以          175352                1728.7798
# 73       超过          157159                1549.4166
# 76       大家          152791                1506.3529
# 80       一起          150536                1484.1210
# 82       快乐          146761                1446.9036
# 84       这个          146176                1441.1362
# 88       知道          138799                1368.4070
# 91       现在          133130                1312.5168
# 92       新年          132679                1308.0705
# 94       成就          126242                1244.6086
# 95       快来          124892                1231.2991
# 96       速度          123661                1219.1628
# 97       喜欢          122587                1208.5743
# 103      时候          117890                1162.2670
# 107      朋友          117241                1155.8686
# 109      玩家          113716                1121.1159
# 110      你们          113281                1116.8273
# 111      开始          112818                1112.2626
# 113      获取          111070                1095.0292
# 118      地址          105268                1037.8278
# 119      怎么          103902                1024.3606
# 120      幸福          102827                1013.7622
# ...     ...             ...                      ...
# 21175   左向右              19                   0.1873
# 21176   汽油味              19                   0.1873
# 21177  东施效颦              19                   0.1873
# 21178    烧包              19                   0.1873
# 21179    树人              19                   0.1873
# 21180    译本              19                   0.1873
# 21181    无伦              19                   0.1873
# 21182  秦皇岛市              19                   0.1873
# 21183  星罗棋布              19                   0.1873
# 21184    多分              19                   0.1873
# 21185   退休证              19                   0.1873
# 21186    家闲              19                   0.1873
# 21187  巴洛克式              19                   0.1873
# 21188   玄关处              19                   0.1873
# 21189    都俾              19                   0.1873
# 21191    怕事              19                   0.1873
# 21192   何星座              19                   0.1873
# 21193   韩范儿              19                   0.1873
# 21194    修为              19                   0.1873
# 21195    头筹              19                   0.1873
# 21196    芬芬              19                   0.1873
# 21197    玩死              19                   0.1873
# 21198    泅渡              19                   0.1873
# 21199    让她              19                   0.1873
# 21200    阿伤              19                   0.1873
# 21201   伤心处              19                   0.1873
# 21202    安尚              19                   0.1873
# 21203   火浇油              19                   0.1873
# 21204   阿米巴              19                   0.1873
# 21205    合水              19                   0.1873
#
# [19263 rows x 3 columns]

# %% [markdown]
# #### Step 2: Creating and removing the necessary and unnecessary columns

# %%
multigram_df['first_char'] = multigram_df['Index'].str[0]
multigram_df['subsequent_char'] = multigram_df['Index'].str[1:]
multigram_df.drop(columns=['Index','Absolute Count'],inplace=True)
# Out:
# C:\Users\Lenovo\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\Lenovo\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\Lenovo\Anaconda3\lib\site-packages\pandas\core\frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
multigram_df['phrase_freq'] = multigram_df['subsequent_char']+':'+multigram_df['Frequency/Million words'].round(4).astype('str')
multigram_df.drop(columns=['Frequency/Million words','subsequent_char'],inplace=True)
# Out:
# C:\Users\Lenovo\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\Lenovo\Anaconda3\lib\site-packages\pandas\core\frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
multigram_df.head(5)
# Out:
#    first_char  phrase_freq
# 34          自  己:2865.3643
# 49          分   享:2191.557
# 51          我  们:2104.5423
# 52          今  天:2039.2172
# 53          一  下:1994.0732

# %%
multigram_df['first_char'].value_counts()
# Out:
# 大    219
# 一    130
# 小    121
# 不    109
# 无    108
# 天     94
# 上     89
# 心     88
# 发     83
# 开     83
# 好     83
# 人     82
# 打     81
# 出     81
# 老     79
# 高     70
# 有     69
# 自     68
# 中     67
# 相     60
# 新     57
# 下     57
# 回     54
# 微     54
# 海     52
# 年     52
# 金     50
# 看     48
# 长     48
# 公     48
#     ...
# 拯      1
# 箭      1
# 蒲      1
# 姊      1
# 茄      1
# 俱      1
# 勉      1
# 禽      1
# 嘱      1
# 梓      1
# 芯      1
# 噱      1
# 撤      1
# 潇      1
# 辫      1
# 苹      1
# 鲸      1
# 哑      1
# 拦      1
# 琉      1
# 迹      1
# 扇      1
# 贡      1
# 囍      1
# 蟑      1
# 汹      1
# 赣      1
# 椰      1
# 扒      1
# 荤      1
# Name: first_char, Length: 2823, dtype: int64

# %% [markdown]
# #### Step 3: Apply a groupby function grouped by first_char and combining all phrase freq data

# %%
firstchar_group = multigram_df.groupby(['first_char']).agg({'phrase_freq':lambda x: ','.join(x)})

# %%
firstchar_group.head(20)
# Out:
#                                                   phrase_freq
# first_char
# 一           下:1994.0732,起:1484.121,样:702.8023,直:548.4808,定...
# 丁                                                    丁:4.3281
# 七           十二:15.7743,点:12.5208,点半:6.566,十七:4.89,彩:3.5788...
# 万           事如意:66.5476,物:14.6405,一:12.5603,事:10.9138,历:8....
# 丈                                          夫:32.1302,母娘:5.452
# 三           十:60.3858,星:53.1888,尺:24.4501,点:24.0557,亚:20.4...
# 上           班:402.1548,海:212.8835,网:111.5043,传:80.1037,帝:7...
# 下           载:934.6248,午:283.7296,来:178.6533,去:176.6717,雨:...
# 不           过:433.2301,管:415.4939,错:341.5915,断:155.6131,同:...
# 与           众不同:7.8871,否:5.8661,其:3.8647,时俱进:2.1098,世隔绝:1.745
# 丑                                 闻:10.6279,陋:6.1322,丑:0.7789
# 专           业:90.0119,属:79.0389,辑:40.5793,家:37.4343,柜:27.9...
# 且                                                   卖萌:1.1732
# 世           界:785.7355,上:57.0141,纪:42.4525,间:30.1091,人:10....
# 丙                                                    肝:0.1873
# 业           务:24.2233,绩:11.2786,主:8.2815,余:3.6478,内:3.2534...
# 丛                                                     生:0.976
# 东           西:593.1318,方:70.8067,莞:22.5966,东:21.6107,北:21....
# 丝                        丝:15.4883,毫:8.1435,袜:7.7688,带:1.7549
# 丢           掉:11.387,失:8.9618,脸:8.8533,人:8.6068,下:5.5999,弃...

# %% [markdown]
# Great. Now we have the information we need. For each first character, we can see the following possible phrases and its frequencies.
#
# For example, 一下 has a frequency of 1994.0732 and 一起 has a frequency of 1484.121.
#
# Now, we just have to transform the phrase_freq column into a hashmap format and save the file as a JSON.

# %%
def extract_phrase(row):
    multigram_json = {}
    phrases_freq = row['phrase_freq'].split(',')
    for phrase_freq in phrases_freq:
        phrase,freq = phrase_freq.split(':')[0],phrase_freq.split(':')[1]
        multigram_json[phrase] = freq
    return multigram_json

firstchar_group['dict'] = firstchar_group.apply(extract_phrase,axis=1)
firstchar_group.drop(columns=['phrase_freq'],inplace=True)
firstchar_group.reset_index(inplace=True)

# %%
firstchar_group.head(10)
# Out:
#   first_char                                               dict
# 0          一  {'下': '1994.0732', '起': '1484.121', '样': '702....
# 1          丁                                    {'丁': '4.3281'}
# 2          七  {'十二': '15.7743', '点': '12.5208', '点半': '6.566...
# 3          万  {'事如意': '66.5476', '物': '14.6405', '一': '12.56...
# 4          丈                    {'夫': '32.1302', '母娘': '5.452'}
# 5          三  {'十': '60.3858', '星': '53.1888', '尺': '24.4501...
# 6          上  {'班': '402.1548', '海': '212.8835', '网': '111.5...
# 7          下  {'载': '934.6248', '午': '283.7296', '来': '178.6...
# 8          不  {'过': '433.2301', '管': '415.4939', '错': '341.5...
# 9          与  {'众不同': '7.8871', '否': '5.8661', '其': '3.8647'...

# %%
def json_dump(row):
    json_data[row['first_char']] = row['dict']

json_data = {}
firstchar_group.apply(json_dump,axis=1)
# Out:
# 0       None
# 1       None
# 2       None
# 3       None
# 4       None
# 5       None
# 6       None
# 7       None
# 8       None
# 9       None
# 10      None
# 11      None
# 12      None
# 13      None
# 14      None
# 15      None
# 16      None
# 17      None
# 18      None
# 19      None
# 20      None
# 21      None
# 22      None
# 23      None
# 24      None
# 25      None
# 26      None
# 27      None
# 28      None
# 29      None
#         ...
# 2793    None
# 2794    None
# 2795    None
# 2796    None
# 2797    None
# 2798    None
# 2799    None
# 2800    None
# 2801    None
# 2802    None
# 2803    None
# 2804    None
# 2805    None
# 2806    None
# 2807    None
# 2808    None
# 2809    None
# 2810    None
# 2811    None
# 2812    None
# 2813    None
# 2814    None
# 2815    None
# 2816    None
# 2817    None
# 2818    None
# 2819    None
# 2820    None
# 2821    None
# 2822    None
# Length: 2823, dtype: object

# %%
json_data
# Out:
# {'一': {'下': '1994.0732',
#   '起': '1484.121',
#   '样': '702.8023',
#   '直': '548.4808',
#   '定': '520.7773',
#   '切': '436.2174',
#   '点': '312.9317',
#   '些': '238.3096',
#   '半': '130.4728',
#   '举': '126.0067',
#   '般': '116.0985',
#   '路': '113.2296',
#   '大早': '87.9809',
#   '唿百应': '62.2097',
#   '边': '61.3619',
#   '会儿': '52.5677',
#   '早': '48.5551',
#   '会': '48.5354',
#   '旦': '40.9046',
#   '点点': '36.2414',
#   '百': '33.7471',
#   '一': '32.9583',
#   '生': '29.7246',
#   '手': '25.7416',
#   '汽': '24.3121',
#   '时': '23.6318',
#   '下子': '22.4882',
#   '辈子': '19.639',
#   '盘': '19.5995',
#   '同': '18.5643',
#   '如既往': '17.1742',
#   '月': '16.7503',
#   '万': '16.2869',
#   '笔': '15.3799',
#   '致': '15.0447',
#   '再': '14.8278',
#   '千': '14.3743',
#   '鸣惊人': '13.9011',
#   '共': '13.4771',
#   '齐': '13.1222',
#   '味': '12.8264',
#   '心': '12.2941',
#   '个': '11.949',
#   '流': '11.7518',
#   '体': '10.7462',
#   '塌煳涂': '10.1843',
#   '口气': '9.5631',
#   '石二鸟': '8.7843',
#   '向': '8.5871',
#   '点儿': '8.5871',
#   '言九鼎': '8.4195',
#   '无所有': '7.5519',
#   '度': '7.404',
#   '个人': '7.3942',
#   '帆风顺': '7.335',
#   '阵子': '7.1477',
#   '日': '7.0097',
#   '次性': '6.9308',
#   '片': '6.7534',
#   '旁': '6.6055',
#   '刻': '6.3393',
#   '心一意': '6.0632',
#   '号': '6.0337',
#   '开始': '5.7675',
#   '模一样': '5.5407',
#   '百多': '5.3632',
#   '行': '5.2745',
#   '眼': '5.2252',
#   '笑': '5.1168',
#   '百万': '4.9788',
#   '亿': '4.9492',
#   '网打尽': '4.4168',
#   '厢情愿': '4.2393',
#   '宿': '4.1407',
#   '生一世': '4.0816',
#   '点半': '3.9041',
#   '律': '3.6084',
#   '千多': '3.5196',
#   '面': '3.4802',
#   '点通': '3.4703',
#   '瞬': '3.4013',
#   '部分': '3.3422',
#   '贯': '3.3027',
#   '千万': '3.2929',
#   '并': '3.2436',
#   '块儿': '3.0661',
#   '臂之力': '3.0267',
#   '往': '2.8788',
#   '二': '2.8394',
#   '举一动': '2.7112',
#   '连': '2.5239',
#   '块': '2.4943',
#   '遍遍': '2.3464',
#   '道': '2.3267',
#   '成不变': '2.1197',
#   '大半': '1.9619',
#   '边倒': '1.9028',
#   '头雾水': '1.7647',
#   '无所知': '1.5676',
#   '系列': '1.5577',
#   '望无际': '1.5577',
#   '模': '1.5478',
#   '遍': '1.3704',
#   '团': '1.3605',
#   '审': '1.3605',
#   '家之主': '1.1732',
#   '觉': '1.1634',
#   '二三': '1.1436',
#   '色': '0.976',
#   '千年': '0.9662',
#   '万多': '0.9662',
#   '清二楚': '0.9563',
#   '下下': '0.7789',
#   '帘幽梦': '0.7789',
#   '体化': '0.7789',
#   '针见血': '0.769',
#   '抖': '0.769',
#   '应俱全': '0.769',
#   '切事': '0.5817',
#   '览表': '0.5718',
#   '念': '0.3845',
#   '半儿': '0.3845',
#   '地': '0.3845',
#   '举手一投足': '0.1873',
#   '点爱': '0.1873',
#   '霎': '0.1873',
#   '下喽': '0.1873',
#   '坨一坨': '0.1873',
#   '百四十': '0.1873',
#   '罐': '0.1873'},
#  '丁': {'丁': '4.3281'},
#  '七': {'十二': '15.7743',
#   '点': '12.5208',
#   '点半': '6.566',
#   '十七': '4.89',
#   '彩': '3.5788',
#   '十': '3.4802',
#   '月': '2.8788',
#   '八': '2.6323',
#   '日': '2.5042',
#   '点多': '2.3563',
#   '上八下': '1.3605',
#   '侠五': '1.3408',
#   '夕': '1.1732',
#   '百': '1.1732',
#   '律': '1.1436',
#   '成': '0.9662',
#   '八点': '0.3845',
#   '百多': '0.3845'},
#  '万': {'事如意': '66.5476',
#   '物': '14.6405',
#   '一': '12.5603',
#   '事': '10.9138',
#   '历': '8.8434',
#   '分': '7.0984',
#   '恶': '5.728',
#   '千': '5.5604',
#   '亿': '5.521',
#   '多': '3.352',
#   '事大吉': '3.1253',
#   '般': '3.0464',
#   '万': '2.8295',
#   '物生': '2.3267',
#   '能': '2.1098',
#   '幸': '2.0802',
#   '余': '1.1634',
#   '圣节': '0.976'},
#  '丈': {'夫': '32.1302', '母娘': '5.452'},
#  '三': {'十': '60.3858',
#   '星': '53.1888',
#   '尺': '24.4501',
#   '点': '24.0557',
#   '亚': '20.4671',
#   '角': '13.8025',
#   '峡': '11.742',
#   '千': '8.528',
#   '寸之舌': '8.3209',
#   '十余': '8.0942',
#   '月': '8.0646',
#   '更半夜': '7.2463',
#   '百': '5.9449',
#   '文鱼': '5.8858',
#   '点半': '5.5801',
#   '岔口': '4.8802',
#   '里屯': '4.752',
#   '生有幸': '4.3774',
#   '分之一': '4.0323',
#   '四': '3.707',
#   '明治': '3.5985',
#   '日': '3.3915',
#   '日月': '3.3619',
#   '点多': '3.283',
#   '十多': '3.2436',
#   '色': '3.2041',
#   '万': '2.4647',
#   '角洲': '2.445',
#   '十六': '2.3563',
#   '轮车': '2.3168',
#   '点钟': '1.9619',
#   '分之二': '1.7155',
#   '百多': '1.3408',
#   '四点': '1.1732',
#   '十五': '1.1535',
#   '个人': '0.5817'},
#  '上': {'班': '402.1548',
#   '海': '212.8835',
#   '网': '111.5043',
#   '传': '80.1037',
#   '帝': '74.3559',
#   '午': '61.6478',
#   '面': '55.6733',
#   '课': '54.1057',
#   '去': '49.1171',
#   '学': '46.1298',
#   '车': '32.7513',
#   '线': '26.8853',
#   '来': '26.067',
#   '涨': '25.1599',
#   '映': '24.5783',
#   '升': '23.9966',
#   '床': '22.6459',
#   '市': '22.6065',
#   '天': '21.6009',
#   '演': '18.3869',
#   '火': '15.9517',
#   '下': '15.3109',
#   '上': '13.5166',
#   '司': '13.3095',
#   '路': '13.1222',
#   '架': '11.1307',
#   '辈子': '10.7364',
#   '瘾': '9.7998',
#   '街': '9.1096',
#   '厕所': '9.0603',
#   '班族': '8.6561',
#   '门': '8.6167',
#   '身': '8.1632',
#   '图': '7.6801',
#   '场': '7.3055',
#   '阵': '7.2956',
#   '榜': '7.1871',
#   '衣': '6.8421',
#   '台': '6.8026',
#   '联': '6.5562',
#   '手': '6.0337',
#   '海市': '5.9153',
#   '级': '4.7619',
#   '坟': '4.683',
#   '山': '4.3675',
#   '行': '4.2295',
#   '方': '4.1407',
#   '扬': '4.1112',
#   '进': '4.052',
#   '吐': '4.0027',
#   '到': '3.9534',
#   '班咯': '3.8647',
#   '证': '3.6577',
#   '半年': '3.4506',
#   '海人': '3.4506',
#   '当': '3.4309',
#   '空': '3.3915',
#   '心': '3.3816',
#   '香': '3.352',
#   '述': '3.3027',
#   '楼': '3.2633',
#   '前': '3.0661',
#   '头': '3.0464',
#   '夜班': '3.0267',
#   '色': '2.9478',
#   '菜': '2.9281',
#   '下班': '2.9182',
#   '调': '2.7112',
#   '进心': '2.652',
#   '铺': '2.0999',
#   '镜': '2.0901',
#   '访': '1.9422',
#   '苍': '1.9323',
#   '完': '1.9126',
#   '岗': '1.7647',
#   '早班': '1.745',
#   '层': '1.5676',
#   '限': '1.5676',
#   '妆': '1.5478',
#   '师': '1.538',
#   '交': '1.3605',
#   '班喽': '1.3507',
#   '牌': '0.7789',
#   '上下下': '0.7789',
#   '古': '0.7789',
#   '条': '0.769',
#   '哪': '0.5817',
#   '策': '0.5817',
#   '尉': '0.1873'},
#  '下': {'载': '934.6248',
#   '午': '283.7296',
#   '来': '178.6533',
#   '去': '176.6717',
#   '雨': '163.5298',
#   '雪': '133.4995',
#   '班': '83.3965',
#   '面': '58.1281',
#   '酒': '49.5115',
#   '降': '29.9119',
#   '车': '23.0206',
#   '辈子': '19.2545',
#   '雨天': '13.5166',
#   '楼': '12.0476',
#   '手': '11.5251',
#   '厨': '9.1589',
#   '巴': '9.0998',
#   '跌': '9.0209',
#   '场': '8.7449',
#   '课': '8.6758',
#   '联': '8.0054',
#   '属': '7.6308',
#   '下': '6.9012',
#   '半场': '6.8421',
#   '起': '6.5069',
#   '图': '6.4773',
#   '定': '6.3689',
#   '调': '5.6393',
#   '床': '4.8999',
#   '半年': '4.8506',
#   '肚': '4.4858',
#   '山': '4.2098',
#   '滑': '4.1703',
#   '雪咯': '3.9041',
#   '乡': '3.5196',
#   '岗': '3.3619',
#   '线': '3.2633',
#   '方': '3.2239',
#   '锅': '3.1056',
#   '身': '3.007',
#   '年': '2.9281',
#   '摆': '2.8788',
#   '南洋': '2.8196',
#   '水': '2.7309',
#   '泻': '2.6323',
#   '列': '2.2971',
#   '行': '2.2873',
#   '回': '2.1492',
#   '头': '2.1098',
#   '蛋': '2.0802',
#   '有': '1.9225',
#   '跪': '1.745',
#   '铺': '1.5577',
#   '发': '1.1732',
#   '饭': '1.1634',
#   '放': '1.1634',
#   '家': '0.5817'},
#  '不': {'过': '433.2301',
#   '管': '415.4939',
#   '错': '341.5915',
#   '断': '155.6131',
#   '同': '146.533',
#   '然': '76.3868',
#   '少': '66.2815',
#   '如': '55.4367',
#   '得不': '48.0129',
#   '仅': '45.4101',
#   '爽': '42.975',
#   '到': '38.5878',
#   '知不觉': '36.5667',
#   '幸': '24.3909',
#   '良': '23.6022',
#   '论': '22.3107',
#   '足': '18.2981',
#   '见': '16.632',
#   '但': '15.2616',
#   '舍': '15.232',
#   '久': '14.7785',
#   '安': '14.6799',
#   '渝': '14.1771',
#   '得了': '13.5954',
#   '满': '13.1715',
#   '止': '13.0532',
#   '妨': '13.0532',
#   '时': '12.4124',
#   '管是': '11.2194',
#   '知所措': '10.0364',
#   '用': '9.9674',
#   '禁': '9.4744',
#   '为人知': '8.6561',
#   '愧': '8.6265',
#   '堪': '8.3998',
#   '已': '7.9068',
#   '对咯': '7.6702',
#   '理': '7.6604',
#   '至于': '7.6308',
#   '许': '7.4928',
#   '解': '7.3942',
#   '败之地': '7.335',
#   '眠': '6.8815',
#   '明': '6.6843',
#   '屑': '6.635',
#   '懈': '6.0829',
#   '经意': '5.9646',
#   '见不散': '5.8562',
#   '当': '5.8463',
#   '利': '5.8168',
#   '亦乐乎': '5.4125',
#   '适': '5.2548',
#   '信': '4.8309',
#   '料': '4.5154',
#   '见得': '4.2393',
#   '幸福': '4.1013',
#   '可思议': '3.9337',
#   '够': '3.8844',
#   '便': '3.7267',
#   '是': '3.6182',
#   '锈': '3.4703',
#   '可或缺': '3.4408',
#   '一定': '3.4112',
#   '错吧': '3.3915',
#   '复': '3.2633',
#   '公': '3.1351',
#   '同以往': '3.0267',
#   '免': '2.938',
#   '论是': '2.7408',
#   '言': '2.7408',
#   '见了': '2.7112',
#   '快乐': '2.6619',
#   '定': '2.5535',
#   '愉快': '2.5337',
#   '慎': '2.5337',
#   '约而同': '2.5239',
#   '落人后': '2.4844',
#   '屑一顾': '2.445',
#   '切实际': '2.445',
#   '羁': '2.3563',
#   '辞': '2.3563',
#   '灭': '2.1492',
#   '同于': '2.1394',
#   '孕': '1.9619',
#   '争': '1.9521',
#   '甘心': '1.9225',
#   '规则': '1.9225',
#   '惜': '1.7549',
#   '等于': '1.745',
#   '凡': '1.7352',
#   '舍得': '1.5676',
#   '卑不亢': '1.5478',
#   '大不小': '1.5478',
#   '等': '1.3605',
#   '妥': '1.3507',
#   '折不扣': '1.1732',
#   '仅仅': '1.1732',
#   '绝于耳': '1.1732',
#   '期而至': '1.1634',
#   '惧': '1.1436',
#   '善于': '0.976',
#   '动声色': '0.7789',
#   '明不白': '0.769',
#   '可磨灭': '0.5817',
#   '经': '0.5817',
#   '自由': '0.5817',
#   '同凡响': '0.5817',
#   '忍': '0.5817',
#   '过瘾': '0.3845'},
#  '与': {'众不同': '7.8871',
#   '否': '5.8661',
#   '其': '3.8647',
#   '时俱进': '2.1098',
#   '世隔绝': '1.745'},
#  '丑': {'闻': '10.6279', '陋': '6.1322', '丑': '0.7789'},
#  '专': {'业': '90.0119',
#   '属': '79.0389',
#   '辑': '40.5793',
#   '家': '37.4343',
#   '柜': '27.9697',
#   '门': '17.0461',
#   '用': '9.6815',
#   '题': '8.9618',
#   '注': '8.666',
#   '一': '8.5082',
#   '心': '7.4435',
#   '场': '6.1027',
#   '利': '5.2055',
#   '车': '4.8802',
#   '卖': '4.5745',
#   '访': '4.3675',
#   '线': '3.4013',
#   '情': '2.3563',
#   '栏': '2.3168',
#   '职': '2.1492',
#   '项': '1.9323',
#   '注于': '1.9028',
#   '业户': '1.7253',
#   '程': '1.538',
#   '享': '0.9563',
#   '家们': '0.7789'},
#  '且': {'卖萌': '1.1732'},
#  '世': {'界': '785.7355',
#   '上': '57.0141',
#   '纪': '42.4525',
#   '间': '30.1091',
#   '人': '10.6378',
#   '俗': '8.3308',
#   '事': '7.9561',
#   '故': '7.6604',
#   '道': '7.5519',
#   '家': '3.0267',
#   '外': '2.4844',
#   '博': '2.4746',
#   '子': '1.9422',
#   '茂': '0.769'},
#  '丙': {'肝': '0.1873'},
#  '业': {'务': '24.2233',
#   '绩': '11.2786',
#   '主': '8.2815',
#   '余': '3.6478',
#   '内': '3.2534',
#   '务员': '1.5676'},
#  '丛': {'生': '0.976'},
#  '东': {'西': '593.1318',
#   '方': '70.8067',
#   '莞': '22.5966',
#   '东': '21.6107',
#   '北': '21.2755',
#   '京': '16.5728',
#   '风': '15.9024',
#   '北风': '12.8757',
#   '邪': '11.9391',
#   '海': '5.9548',
#   '去': '5.7083',
#   '南': '5.4027',
#   '门': '5.0872',
#   '部': '4.1605',
#   '莫村': '3.9238',
#   '北亚': '3.6379',
#   '城': '2.4549',
#   '边': '2.1295',
#   '湖': '1.9225',
#   '家': '1.1634',
#   '莞市': '0.976',
#   '芝': '0.769',
#   '奔西跑': '0.5817',
#   '瀛': '0.3845',
#   '大街': '0.3845',
#   '钱湖': '0.1873',
#   '施效颦': '0.1873'},
#  '丝': {'丝': '15.4883', '毫': '8.1435', '袜': '7.7688', '带': '1.7549'},
#  '丢': {'掉': '11.387',
#   '失': '8.9618',
#   '脸': '8.8533',
#   '人': '8.6068',
#   '下': '5.5999',
#   '弃': '4.821',
#   '开': '2.4844',
#   '到': '1.3408',
#   '三落四': '1.1436',
#   '丢': '0.976'},
#  '两': {'厢': '6.4379',
#   '千': '5.797',
#   '个': '5.7872',
#   '百': '4.89',
#   '万': '4.19',
#   '点': '3.5985',
#   '点半': '3.1154',
#   '千多': '1.9225',
#   '样': '1.745',
#   '三': '0.9662'},
#  '严': {'重': '77.7375',
#   '寒': '15.5968',
#   '肃': '13.0335',
#   '格': '9.9969',
#   '厉': '4.4858',
#   '谨': '3.7562',
#   '禁': '2.1098',
#   '峻': '1.3507',
#   '歌苓': '0.3845'},
#  '丧': {'失': '8.2815', '尸': '1.3408'},
#  '个': {'人': '106.4072',
#   '个': '59.7647',
#   '性': '51.4339',
#   '态': '17.1939',
#   '澡': '10.5688',
#   '股': '8.9322',
#   '头': '8.3998',
#   '屁': '7.4435',
#   '微博仙': '5.521',
#   '月': '4.9492',
#   '子': '4.8506',
#   '体': '4.7816',
#   '别': '4.5252',
#   '小时': '3.7267',
#   '啥': '3.6478',
#   '儿': '3.4999',
#   '样': '3.4703',
#   '好': '2.9182',
#   '活动': '2.0999',
#   '性化': '2.0999',
#   '新': '0.7789',
#   '国': '0.1873',
#   '色': '0.1873',
#   '脸': '0.1873'},
#  '丫': {'头': '14.4137', '丫': '3.2929', '说': '1.9225', '的': '1.7155'},
#  '中': {'国': '475.3375',
#   '午': '128.2841',
#   '国人': '93.5808',
#   '心': '89.4598',
#   '奖': '63.3238',
#   '间': '39.1596',
#   '文': '35.4428',
#   '意': '34.0823',
#   '华': '29.9711',
#   '央': '26.2641',
#   '学': '21.3938',
#   '级': '18.8798',
#   '长': '16.9475',
#   '山': '16.2475',
#   '转': '16.0503',
#   '毒': '13.7039',
#   '天': '12.649',
#   '雨': '11.5448',
#   '医': '11.5152',
#   '国式': '10.3913',
#   '年': '9.8392',
#   '免费': '9.2082',
#   '药': '8.7449',
#   '途': '7.9068',
#   '饭': '7.0097',
#   '性': '6.0139',
#   '度': '5.8562',
#   '式': '5.6294',
#   '奖率': '5.59',
#   '场': '5.1661',
#   '文网': '5.0872',
#   '等': '4.9196',
#   '长款': '4.8604',
#   '共': '4.3675',
#   '雪': '3.9436',
#   '餐': '3.9238',
#   '号': '3.7562',
#   '原': '3.6774',
#   '午饭': '3.6577',
#   '分': '3.6478',
#   '考': '3.6379',
#   '路': '3.3323',
#   '新网': '3.214',
#   '文版': '3.2041',
#   '去': '3.0365',
#   '外': '3.0168',
#   '部': '2.8788',
#   '环': '2.652',
#   '关村': '2.652',
#   '指': '2.652',
#   '兴': '2.4844',
#   '老年': '2.4844',
#   '庸': '2.445',
#   '介': '2.3464',
#   '东': '2.3168',
#   '断': '2.2971',
#   '行': '2.2971',
#   '方': '2.1197',
#   '期': '1.9422',
#   '学生': '1.7352',
#   '锋': '1.5676',
#   '旬': '1.5478',
#   '枢': '1.3507',
#   '时': '0.769',
#   '科院': '0.769',
#   '国馆': '0.5817',
#   '医学': '0.1873'},
#  '丰': {'富': '66.0646',
#   '盛': '34.309',
#   '厚': '27.1514',
#   '收': '9.4941',
#   '富多彩': '9.3955',
#   '年': '9.2378',
#   '满': '5.8168',
#   '登': '5.3238',
#   '田': '3.1253',
#   '衣足食': '2.3563'},
#  '串': {'门': '7.6998', '串': '3.6478', '烧': '2.3168'},
#  '临': {'门': '18.5643',
#   '时': '14.7785',
#   '近': '14.2067',
#   '时工': '5.2844',
#   '安府': '4.052',
#   '走': '3.0957',
#   '床': '2.6915',
#   '沂': '2.0802',
#   '风': '0.9662',
#   '产': '0.5817'},
#  '丸': {'子': '21.1079'},
#  '丹': {'麦': '3.9534'},
#  '为': {'什么': '468.9588',
#   '了': '323.254',
#   '何': '48.8608',
#   '啥': '33.3231',
#   '止': '17.0658',
#   '主': '13.8912',
#   '难': '6.0829',
#   '荣': '3.2633',
#   '期': '2.7112',
#   '甚么': '2.6619',
#   '辅': '2.1295',
#   '乐': '1.745',
#   '人': '1.5577',
#   '生': '1.5478',
#   '善': '1.3507',
#   '证': '0.7789',
#   '己': '0.3845'},
#  '主': {'题': '391.4776',
#   '角': '135.2051',
#   '要': '57.7042',
#   '持人': '42.9454',
#   '动': '41.7821',
#   '人': '32.9781',
#   '持': '24.4107',
#   '页': '23.0403',
#   '任': '18.8207',
#   '宰': '18.2784',
#   '演': '14.601',
#   '席': '11.7321',
#   '场': '11.6927',
#   '题曲': '9.2181',
#   '播': '7.6407',
#   '力': '7.2463',
#   '管': '6.7829',
#   '意': '6.6843',
#   '流': '6.6252',
#   '食': '6.2111',
#   '妇': '5.6492',
#   '见': '5.4125',
#   '观': '4.4661',
#   '打': '4.259',
#   '张': '3.8647',
#   '人公': '3.4408',
#   '体': '3.1351',
#   '权': '3.1056',
#   '唱': '2.8788',
#   '导': '2.6816',
#   '啊': '2.445',
#   '线': '1.745',
#   '编': '1.7155',
#   '办方': '1.3605',
#   '银': '1.1436',
#   '菜': '1.1436',
#   '因': '0.769',
#   '楼': '0.3845',
#   '科': '0.1873'},
#  '丽': {'江': '16.4348', '人': '2.5436', '贝卡': '1.3408'},
#  '举': {'行': '23.2079',
#   '办': '19.1361',
#   '手': '18.1601',
#   '起': '8.9223',
#   '报': '5.2942',
#   '动': '4.5647',
#   '止': '3.3717',
#   '手投足': '3.0858',
#   '杯': '2.6323',
#   '头': '1.5676',
#   '步维艰': '0.3845'},
#  '乃': {'至': '3.3816', '们': '3.283'},
#  '久': {'违': '25.1106',
#   '远': '16.3658',
#   '久': '6.3787',
#   '而久之': '2.7506',
#   '治不愈': '0.1873'},
#  '么': {'么': '11.3377',
#   '办': '4.4267',
#   '多': '3.6182',
#   '么哒': '0.5817',
#   '事': '0.3845'},
#  '义': {'气': '16.0404', '务': '8.3801', '无反顾': '5.6886', '乌': '2.445'},
#  '之': {'后': '208.6047',
#   '前': '152.1427',
#   '间': '104.1495',
#   '禄': '48.4861',
#   '一': '41.6736',
#   '中': '38.0554',
#   '外': '26.9148',
#   '所以': '21.8276',
#   '类': '17.6277',
#   '下': '16.1588',
#   '恋': '15.7545',
#   '际': '14.7785',
#   '内': '8.8632',
#   '上': '7.3547',
#   '战': '4.2985',
#   '余': '3.707',
#   '友': '1.1732'},
#  '乌': {'龟': '8.9716',
#   '鸦': '8.804',
#   '镇': '5.5604',
#   '鲁木齐': '5.0379',
#   '龙': '4.4858',
#   '云': '2.6816'},
#  '乍': {'看': '0.3845'},
#  '乎': {'乎': '2.2774'},
#  '乏': {'味': '17.5094', '力': '3.4605'},
#  '乐': {'园': '208.161',
#   '趣': '38.0258',
#   '观': '26.7571',
#   '排网': '11.9194',
#   '队': '10.0758',
#   '乐': '9.5336',
#   '意': '7.4632',
#   '于助人': '4.3182',
#   '善好施': '4.1703',
#   '团': '4.0717',
#   '逗': '3.9731',
#   '事': '3.8253',
#   '善': '3.8055',
#   '器': '3.7562',
#   '视': '3.6872',
#   '于': '2.8295',
#   '坛': '2.4549',
#   '库': '2.3464',
#   '园亲': '2.2675',
#   '此不疲': '2.1197',
#   '得': '1.9619',
#   '嘉': '1.9323',
#   '么': '1.745',
#   '清': '0.9662',
#   '迪量贩式': '0.9563'},
#  '乒': {'乓球': '3.983', '乓': '0.5817'},
#  '乔': {'布斯': '8.1533', '丹': '3.7168'},
#  '乖': {'乖': '34.9104', '巧': '3.8647'},
#  '乘': {'客': '13.5954',
#   '坐': '8.4392',
#   '务员': '3.283',
#   '车': '2.9478',
#   '机': '1.9126',
#   '风': '0.769'},
#  '乜': {'野': '1.9619', '鬼': '0.3845'},
#  '九': {'点': '16.0799',
#   '九': '10.0659',
#   '妹': '7.6407',
#   '点半': '4.9492',
#   '品': '3.983',
#   '寨沟': '3.7661',
#   '月': '3.6577',
#   '五': '2.3464',
#   '州': '1.7253',
#   '二': '1.1732',
#   '号': '0.3845',
#   '零后': '0.1873'},
#  '乞': {'丐': '10.9533', '讨': '3.5985', '儿': '2.6816', '求': '2.3366'},
#  '也': {'许': '191.0065', '好': '8.3801', '是': '2.3366'},
#  '习': {'惯': '211.2567', '俗': '12.8264', '惯性': '11.3673'},
#  '乡': {'村': '30.3654',
#   '里': '26.343',
#   '下': '20.2305',
#   '间': '2.2873',
#   '亲': '1.9028'},
#  '书': {'写': '91.3527',
#   '记': '11.9786',
#   '店': '10.4307',
#   '城': '8.5082',
#   '包': '7.9364',
#   '法': '6.9703',
#   '籍': '6.4872',
#   '签': '5.4125',
#   '架': '4.6041',
#   '房': '4.3774',
#   '本': '3.6577',
#   '桌': '3.145',
#   '评': '2.8887',
#   '生': '1.5577',
#   '来': '1.3408',
#   '呆子': '0.5817',
#   '立': '0.1873'},
#  '买': {'到': '42.9158',
#   '张': '25.4163',
#   '单': '9.6716',
#   '来': '7.5618',
#   '卖': '7.128',
#   '家': '6.0731',
#   '票': '4.3478',
#   '好': '3.2041',
#   '入': '2.8689',
#   '下': '2.1197',
#   '么': '0.5817'},
#  '乱': {'世': '214.6186',
#   '七八糟': '19.6094',
#   '世佳人': '6.4872',
#   '想': '2.8394',
#   '糟糟': '1.745',
#   '撞': '0.5817',
#   '象': '0.3845',
#   '放': '0.3845'},
#  '乳': {'房': '7.4829',
#   '液': '4.8802',
#   '腺癌': '2.6718',
#   '酪': '2.3366',
#   '汁': '2.3267',
#   '沟': '1.7253',
#   '牙': '0.769',
#   '霜': '0.5817'},
#  '了': {'解': '95.4737',
#   '么': '48.427',
#   '不起': '11.9293',
#   '哟': '3.2239',
#   '事': '1.745',
#   '咯': '1.3507'},
#  '争': {'夺': '31.6372',
#   '取': '29.8331',
#   '吵': '13.2109',
#   '气': '11.2885',
#   '执': '7.2759',
#   '议': '7.0195',
#   '霸': '5.5999',
#   '锋': '4.6534',
#   '论': '4.5154',
#   '辩': '3.4703',
#   '斗': '1.5676',
#   '论不休': '0.9662',
#   '先恐后': '0.7789',
#   '议性': '0.1873'},
#  '事': {'情': '391.6452',
#   '业': '101.5566',
#   '成': '64.7336',
#   '实': '55.6733',
#   '件': '53.7113',
#   '儿': '51.8776',
#   '事': '38.7258',
#   '物': '27.4275',
#   '故': '21.7981',
#   '变': '7.5026',
#   '后': '5.5407',
#   '业有成': '5.4125',
#   '项': '5.3632',
#   '先': '4.5943',
#   '务': '3.8351',
#   '宜': '2.1591',
#   '件簿': '1.7253',
#   '半功倍': '1.5478',
#   '么': '1.1535',
#   '态': '1.1535',
#   '发': '1.1535',
#   '关': '0.769',
#   '上': '0.1873'},
#  '二': {'十': '45.8932',
#   '十四': '28.7091',
#   '郎神': '15.725',
#   '维码': '12.4419',
#   '奶': '9.1491',
#   '胡': '9.0308',
#   '十九': '8.7251',
#   '十多': '8.0547',
#   '十八': '7.1083',
#   '十三': '6.9801',
#   '月': '6.9505',
#   '十五': '5.7576',
#   '十几': '5.028',
#   '手房': '4.5844',
#   '姐': '4.1999',
#   '十七': '4.052',
#   '十一': '3.776',
#   '哥': '3.7562',
#   '十六': '3.5689',
#   '手': '3.3422',
#   '百五': '2.4943',
#   '十二': '2.1197',
#   '百': '2.1098',
#   '手烟': '1.5281',
#   '月份': '1.1535',
#   '三十': '1.1535',
#   '零一二': '0.976',
#   '一': '0.976',
#   '手车': '0.9662',
#   '十分': '0.5817'},
#  '于': {'是': '127.594',
#   '是乎': '4.5548',
#   '心': '3.0464',
#   '谦': '1.9422',
#   '世': '0.5817',
#   '今': '0.1873'},
#  '亏': {'啦': '4.0422',
#   '损': '3.983',
#   '待': '3.0464',
#   '欠': '1.9521',
#   '本': '1.5676'},
#  '云': {'南': '17.332',
#   '霄': '3.7957',
#   '端': '3.3126',
#   '彩': '2.6323',
#   '雾': '2.2774',
#   '吞': '1.7253',
#   '层': '1.5676',
#   '烟': '1.5478'},
#  '互': {'粉': '52.5579',
#   '相': '40.8455',
#   '动': '27.3979',
#   '掐': '22.4586',
#   '联': '21.0685',
#   '联网': '19.7671',
#   '助': '2.7408',
#   '换': '1.7549',
#   '访': '0.9662',
#   '爱': '0.1873'},
#  '五': {'彩': '48.2002',
#   '点': '27.4472',
#   '百': '20.3389',
#   '十': '11.0814',
#   '月': '10.7955',
#   '月天': '9.0603',
#   '星级': '7.6209',
#   '点半': '6.8421',
#   '星': '6.3787',
#   '一': '5.5111',
#   '千万': '4.5351',
#   '点多': '4.5252',
#   '千': '3.3619',
#   '粮液': '2.9182',
#   '角场': '2.3464',
#   '点钟': '1.9521',
#   '万': '1.9323',
#   '体投地': '1.7155',
#   '味': '1.3704',
#   '百多': '0.7789',
#   '华县': '0.1873'},
#  '井': {'井': '0.1873'},
#  '亚': {'军': '30.9471',
#   '洲': '17.7855',
#   '历山大': '3.7957',
#   '马逊': '3.7267',
#   '当': '3.4506',
#   '龙湾': '1.745',
#   '运会': '0.3845'},
#  '些': {'许': '9.0505', '话': '1.7352', '啥': '0.7789'},
#  '亡': {'灵': '2.9084', '国': '1.5577'},
#  '亢': {'奋': '6.152'},
#  '交': {'通': '48.8903',
#   '友': '45.2524',
#   '流': '30.5528',
#   '易': '21.8868',
#   '往': '18.0221',
#   '警': '16.9672',
#   '给': '16.1095',
#   '换': '9.4744',
#   '响曲': '7.7984',
#   '代': '6.3097',
#   '集': '6.3097',
#   '际': '5.521',
#   '锋': '5.452',
#   '谈': '5.383',
#   '替': '5.2351',
#   '错': '4.614',
#   '织': '3.5196',
#   '卷': '3.4901',
#   '心': '3.4802',
#   '叉': '3.2633',
#   '待': '3.0563',
#   '易日': '2.9971',
#   '配': '2.6816',
#   '加': '2.5239',
#   '费': '2.4647',
#   '出': '1.7549',
#   '钱': '1.3605',
#   '规': '0.5817'},
#  '亦': {'然': '0.5817'},
#  '产': {'品': '75.1249',
#   '生': '46.1989',
#   '业': '12.7377',
#   '物': '2.4549',
#   '权': '2.2971',
#   '后': '2.2873',
#   '地': '1.7352',
#   '妇': '1.5281'},
#  '亨': {'利': '7.7787', '通': '4.7619'},
#  '享': {'受': '155.7609',
#   '乐': '22.2417',
#   '自': '14.0785',
#   '用': '4.4267',
#   '有': '3.4605',
#   '福': '3.3126',
#   '原': '1.5478'},
#  '京': {'东': '10.7561',
#   '城': '4.5844',
#   '剧': '4.3281',
#   '珠': '3.0365',
#   '津': '0.7789',
#   '师': '0.3845'},
#  '亮': {'点': '36.1625',
#   '相': '10.6082',
#   '片': '9.0702',
#   '亮': '8.8632',
#   '瞎': '3.8351',
#   '丽': '3.8253',
#   '色': '2.1492'},
#  '亲': {'爱': '241.8391',
#   '们': '107.0579',
#   '戚': '58.207',
#   '刚': '50.5861',
#   '人': '33.2935',
#   '情': '32.1795',
#   '密': '28.9556',
#   '入': '28.8275',
#   '切': '20.3981',
#   '自': '15.9813',
#   '亲': '15.656',
#   '朋好友': '14.5518',
#   '手': '13.9011',
#   '爱的们': '11.7913',
#   '近': '8.8829',
#   '友': '7.3942',
#   '吻': '7.335',
#   '子': '5.4421',
#   '戚家': '4.7421',
#   '身': '4.3872',
#   '眼': '4.3182',
#   '家': '4.2985',
#   '朋': '4.1407',
#   '生': '3.8943',
#   '口': '2.9281',
#   '戚们': '2.8591',
#   '娘': '2.652',
#   '测': '2.5535',
#   '热': '2.0999',
#   '属': '1.5676',
#   '爹': '1.3408',
#   '故': '1.1634',
#   '嘴': '0.7789',
#   '家母': '0.1873'},
#  '人': {'生': '532.3319',
#   '家': '133.2826',
#   '们': '108.5959',
#   '民': '92.8414',
#   '类': '69.0617',
#   '气': '68.9631',
#   '品': '66.6167',
#   '人': '64.5561',
#   '物': '53.6522',
#   '员': '49.9551',
#   '间': '45.42',
#   '心': '39.3371',
#   '口': '33.6583',
#   '才': '32.6527',
#   '民币': '26.7472',
#   '士': '26.0472',
#   '体': '23.7008',
#   '群': '22.3699',
#   '儿': '21.6305',
#   '性': '20.9108',
#   '格': '19.1854',
#   '大': '17.6277',
#   '生路': '13.9898',
#   '际': '13.4081',
#   '爱': '12.9349',
#   '秀': '12.8166',
#   '山人海': '12.4912',
#   '情': '11.4462',
#   '静': '11.2194',
#   '参': '11.0617',
#   '品值': '10.8349',
#   '脉': '10.6871',
#   '次': '10.6378',
#   '少': '10.0561',
#   '数': '10.0265',
#   '造': '9.8392',
#   '好': '9.0899',
#   '事': '8.5575',
#   '海': '8.5378',
#   '非': '8.0153',
#   '工': '6.99',
#   '均': '6.6548',
#   '身': '6.152',
#   '行': '6.1322',
#   '日': '6.0731',
#   '为': '6.0041',
#   '力': '6.0041',
#   '像': '5.9844',
#   '味': '5.9351',
#   '时': '5.9153',
#   '文': '5.8956',
#   '缘': '5.8168',
#   '渣': '5.5703',
#   '流': '4.9788',
#   '么': '4.9492',
#   '话': '4.9393',
#   '头': '4.614',
#   '潮': '4.545',
#   '来人往': '4.2492',
#   '权': '4.19',
#   '选': '4.1802',
#   '民网': '4.1309',
#   '手': '4.1112',
#   '意': '4.0027',
#   '肉': '3.9731',
#   '命': '3.9337',
#   '性化': '3.6577',
#   '世': '3.4408',
#   '生苦短': '3.2337',
#   '影': '3.076',
#   '呐': '2.8492',
#   '生观': '2.6323',
#   '者': '2.1591',
#   '道': '2.1394',
#   '面': '1.9521',
#   '散': '1.5577',
#   '迷': '1.5577',
#   '行道': '1.331',
#   '问': '1.1535',
#   '贱': '0.7789',
#   '网': '0.769',
#   '之智': '0.5817'},
#  '亿': {'万': '5.0379'},
#  '什': {'么': '1993.531', '么样': '50.2312'},
#  '仁': {'心': '3.5295',
#   '寺': '3.5196',
#   '慈': '2.8887',
#   '兄': '2.8689',
#   '爱': '1.3704',
#   '者': '0.976'},
#  '仅': {'仅': '43.9412'},
#  '仇': {'恨': '6.0632', '人': '1.3704', '敌': '0.5817'},
#  '今': {'天': '2039.2172',
#   '年': '508.4832',
#   '晚': '422.0107',
#   '日': '395.1452',
#   '后': '74.3362',
#   '儿': '41.2004',
#   '生': '35.64',
#   '夜': '35.5315',
#   '早': '29.0444',
#   '朝': '11.7321',
#   '开': '6.2013',
#   '次': '4.8111',
#   '世': '3.2929',
#   '晨': '3.2732',
#   '宵': '3.1943',
#   '个': '3.0464'},
#  '介': {'绍': '60.2577',
#   '意': '21.384',
#   '个': '7.2956',
#   '么': '3.7562',
#   '入': '2.938',
#   '于': '2.4943'},
#  '仍': {'然': '38.1836', '旧': '6.2505'},
#  '从': {'来': '163.6086',
#   '此': '55.8014',
#   '前': '31.3908',
#   '事': '17.5193',
#   '而': '13.694',
#   '天而降': '13.2405',
#   '容': '12.8462',
#   '军记': '6.2013',
#   '未': '4.821',
#   '此以后': '3.8154',
#   '头到尾': '3.2436',
#   '今以后': '2.6915',
#   '头': '1.9225',
#   '今': '1.745',
#   '早': '1.5676',
#   '速': '1.3605',
#   '没': '0.9662'},
#  '仓': {'库': '4.1112', '促': '2.2971', '鼠': '1.9225'},
#  '仔': {'细': '25.0909', '仔': '6.4182'},
#  '他': {'们': '500.3693',
#   '人': '52.5283',
#   '妈': '7.266',
#   '乡': '4.752',
#   '么': '1.3408'},
#  '仗': {'义': '1.9422'},
#  '付': {'出': '101.7933', '款': '5.9449', '邮': '3.914', '辛博人气': '0.1873'},
#  '仙': {'境': '7.059',
#   '女': '6.7139',
#   '人': '3.8351',
#   '踪': '3.0957',
#   '界': '1.7647',
#   '子': '1.7253',
#   '草': '1.3704',
#   '贝': '0.3845'},
#  '代': {'表': '114.9352',
#   '价': '22.3304',
#   '替': '16.701',
#   '购': '9.4054',
#   '艳': '7.5223',
#   '笔': '7.0688',
#   '言人': '6.7928',
#   '谢': '6.6252',
#   '理': '5.9351',
#   '言': '5.3041',
#   '金券': '4.4957',
#   '码': '4.0422',
#   '沟': '3.076',
#   '表团': '2.7506',
#   '名词': '1.9225',
#   '售点': '1.538',
#   '代': '0.7789',
#   '发': '0.3845',
#   '表队': '0.1873'},
#  '以': {'后': '356.6855',
#   '为': '238.073',
#   '前': '208.7624',
#   '及': '77.984',
#   '上': '57.7831',
#   '来': '44.9665',
#   '下': '32.5936',
#   '往': '12.4321',
#   '外': '11.9687',
#   '至于': '8.173',
#   '免': '7.4435',
#   '便': '4.4464',
#   '内': '3.7661',
#   '至': '1.7253',
#   '身作则': '0.7789',
#   '爲': '0.3845'},
#  '仪': {'式': '22.0938', '器': '1.5281'},
#  '们': {'都': '6.4576',
#   '一起': '3.283',
#   '还': '2.1295',
#   '要': '2.1098',
#   '是': '1.7253',
#   '新年': '1.3704',
#   '家': '1.3605',
#   '一': '1.1436',
#   '去': '0.9662',
#   '了': '0.3845',
#   '把': '0.1873'},
#  '仰': {'望': '11.5349', '卧': '4.7323', '视': '2.445', '天': '1.3704'},
#  '仲': {'要': '17.3418', '有': '10.4899', '系': '6.5069', '未训': '0.7789'},
#  '价': {'格': '94.6357', '值': '79.7586', '值观': '9.7998', '钱': '7.966'},
#  '任': {'务': '308.5543',
#   '何': '177.7167',
#   '意': '53.3663',
#   '性': '29.5669',
#   '选': '3.0858',
#   '由': '2.6915',
#   '志强': '0.976',
#   '重而道远': '0.5817'},
#  '份': {'子': '19.8066', '量': '3.914', '上': '2.7211', '额': '2.1197'},
#  '仿': {'佛': '32.4358'},
#  '企': {'业': '58.3155',
#   '鹅': '16.1588',
#   '盼': '8.2223',
#   '业家': '5.3041',
#   '图': '4.1999',
#   '划': '0.7789',
#   '噶': '0.5817',
#   '嘅': '0.1873'},
#  '伊': {'朗': '24.8642',
#   '始': '7.1871',
#   '人': '2.6718',
#   '拉克': '2.2873',
#   '甸园': '0.7789',
#   '瓜': '0.5817'},
#  '伍': {'迪艾伦': '0.5817'},
#  '伏': {'特加': '2.3267', '特': '0.1873'},
#  '休': {'息': '149.9738',
#   '闲': '38.4498',
#   '假': '13.349',
#   '息室': '1.7549',
#   '闲裤': '1.7549',
#   '养': '1.7549',
#   '息日': '1.5478',
#   '整': '1.5478',
#   '息够': '0.1873'},
#  '众': {'多': '32.8006',
#   '人': '23.8881',
#   '生': '9.0209',
#   '院': '1.5676',
#   '叛亲离': '0.3845'},
#  '优': {'秀': '47.6481',
#   '雅': '39.3666',
#   '惠': '34.1611',
#   '品': '20.3784',
#   '点': '18.6728',
#   '先': '16.8883',
#   '惠券': '14.4827',
#   '势': '12.7377',
#   '化': '10.2237',
#   '质': '9.8491',
#   '酷': '8.2716',
#   '美': '8.2716',
#   '越感': '5.2252',
#   '柔': '3.7464',
#   '良': '2.652',
#   '生': '2.1098',
#   '待': '0.3845',
#   '雅感': '0.3845',
#   '子': '0.1873'},
#  '伙': {'伴': '12.58', '伴们': '3.0957', '食': '2.8591'},
#  '会': {'儿': '31.0359',
#   '议': '25.8796',
#   '员': '23.7797',
#   '错': '10.273',
#   '长': '8.8533',
#   '计': '7.1576',
#   '心': '4.2788',
#   '死': '4.2196',
#   '场': '3.6182',
#   '见': '3.5886',
#   '有': '3.5886',
#   '好': '2.8295',
#   '员卡': '2.7211',
#   '变': '2.6915',
#   '所': '2.2675',
#   '议室': '1.9521',
#   '馆': '1.7253',
#   '想': '1.3704',
#   '面': '1.1732',
#   '更': '0.5817',
#   '用': '0.5817',
#   '太': '0.3845',
#   '认识': '0.1873',
#   '走': '0.1873'},
#  '伟': {'大': '49.4523', '哥': '2.5337'},
#  '传': {'说': '341.6507',
#   '奇': '94.3991',
#   '统': '41.6243',
#   '递': '18.8207',
#   '来': '13.5461',
#   '播': '13.349',
#   '送': '13.1814',
#   '情': '9.6124',
#   '别': '8.6463',
#   '媒': '7.9956',
#   '人': '7.7097',
#   '染': '7.3942',
#   '书': '6.1125',
#   '承': '4.5844',
#   '给': '3.8154',
#   '闻': '3.5886',
#   '达': '3.0957',
#   '动': '3.0267',
#   '到': '2.7506',
#   '输': '2.3563',
#   '声筒': '1.9028',
#   '销': '1.7253',
#   '送门': '0.9563'},
#  '伤': {'心': '102.4439',
#   '害': '94.8822',
#   '感': '30.464',
#   '口': '22.7248',
#   '痛': '18.1995',
#   '痕': '11.042',
#   '悲': '5.7379',
#   '身': '5.1858',
#   '疤': '4.7224',
#   '痕累累': '3.8548',
#   '神': '2.4647',
#   '不起': '2.1591',
#   '亡': '2.1098',
#   '害人': '1.5478',
#   '脑筋': '1.5281',
#   '病': '1.1535',
#   '心处': '0.1873'},
#  '伦': {'敦': '15.863', '理': '12.8757', '家': '3.2239'},
#  '伪': {'装': '16.3559', '娘': '2.1394', '造': '1.7155', '装成': '0.7789'},
#  '伯': {'伯': '4.3182', '爵': '1.9323', '乐': '1.1732'},
#  '估': {'计': '80.4191', '值': '2.2971'},
#  '伴': {'随': '14.1475',
#   '侣': '12.225',
#   '娘': '10.5392',
#   '奏': '3.8055',
#   '郎': '3.3422'},
#  '伸': {'出': '67.0307',
#   '手': '7.2857',
#   '直': '3.4999',
#   '展': '3.4309',
#   '冤': '2.6619'},
#  '伺': {'候': '7.8773'},
#  '似': {'乎': '63.4125', '的': '6.7435', '火': '0.769'},
#  '但': {'是': '464.2364', '愿': '6.2407'},
#  '位': {'置': '256.8246', '子': '12.087', '于': '3.3422', '数': '2.0999'},
#  '低': {'调': '46.7115',
#   '头': '15.0841',
#   '落': '13.1715',
#   '于': '6.7336',
#   '价': '4.8309',
#   '温': '3.8746',
#   '谷': '3.6182',
#   '级': '3.5591',
#   '估': '3.4802',
#   '下': '3.3619',
#   '俗': '2.4844'},
#  '住': {'院': '7.1773',
#   '房': '7.0787',
#   '宅': '5.5407',
#   '宿': '3.9929',
#   '进': '2.7013',
#   '姐': '2.7013'},
#  '佐': {'料': '1.3704'},
#  '体': {'验': '875.3628',
#   '会': '40.5201',
#   '育': '36.2611',
#   '重': '25.1304',
#   '现': '17.8446',
#   '力': '17.1841',
#   '贴': '14.3546',
#   '谅': '12.4715',
#   '内': '11.7715',
#   '检': '9.5237',
#   '系': '8.7251',
#   '质': '7.5716',
#   '制': '7.0688',
#   '育馆': '6.5463',
#   '温': '5.9942',
#   '弱者': '4.7224',
#   '操': '3.9633',
#   '型': '3.3225',
#   '育场': '2.7506',
#   '味': '2.4647',
#   '育部': '0.7789'},
#  '何': {'必': '44.2764',
#   '时': '39.5047',
#   '以堪': '20.122',
#   '处': '14.5912',
#   '况': '10.1054',
#   '苦': '7.059',
#   '方': '6.5463',
#   '以': '6.2703',
#   '止': '5.8266',
#   '尝': '4.9393',
#   '等': '4.4464',
#   '地': '4.4365',
#   '物': '3.6379',
#   '在': '3.4112',
#   '为': '2.7013',
#   '事': '2.5436',
#   '炅': '2.3563',
#   '求': '1.1732',
#   '星座': '0.1873'},
#  '余': {'地': '4.0717', '额': '2.8295', '粮': '1.9126'},
#  '佛': {'山': '13.7532',
#   '祖': '6.9801',
#   '教': '6.4576',
#   '山市': '6.2505',
#   '珠': '3.5985',
#   '法': '2.7506',
#   '罗伦萨': '2.307',
#   '陀': '1.9521'},
#  '作': {'业': '93.3935',
#   '为': '85.812',
#   '品': '75.3122',
#   '用': '53.0114',
#   '战': '37.3061',
#   '者': '21.0784',
#   '文': '14.4827',
#   '息': '11.742',
#   '家': '10.5885',
#   '出': '7.335',
#   '孽': '7.0886',
#   '弊': '7.0294',
#   '痛': '3.8943',
#   '风': '3.4703',
#   '怪': '2.3267',
#   '秀': '1.9028',
#   '伴': '1.7253',
#   '假': '1.3704',
#   '坊': '1.3408'},
#  '你': {'们': '1116.8273',
#   '妹': '52.4987',
#   '丫': '9.8392',
#   '好': '8.1632',
#   '别': '5.4717',
#   '报': '4.0027',
#   '咯': '3.5393',
#   '咋': '3.4703',
#   '么': '3.0267',
#   '给': '0.5817',
#   '宠': '0.1873'},
#  '佩': {'服': '29.3598', '佩': '6.4773', '戴': '4.0422'},
#  '佬': {'斗': '19.0277'},
#  '佳': {'节': '15.4193',
#   '人': '14.8081',
#   '能': '6.0632',
#   '期': '5.1266',
#   '作': '3.707',
#   '品': '3.4112',
#   '佳': '2.3563',
#   '绩': '1.1535',
#   '礼': '0.3845'},
#  '使': {'用': '151.0188',
#   '劲': '9.0209',
#   '得': '8.6758',
#   '命': '5.6492',
#   '用者': '2.8985',
#   '馆': '2.4647',
#   '者': '2.3267',
#   '用权': '1.5676'},
#  '侃': {'侃': '1.5478'},
#  '侄': {'女': '14.532', '子': '12.9546', '儿': '3.1253'},
#  '例': {'外': '8.7153', '如': '8.4885', '子': '3.4013', '行': '2.514'},
#  '侍': {'者': '0.7789'},
#  '供': {'应': '6.2604', '养': '3.4703', '给': '1.7155', '电': '1.3605'},
#  '依': {'然': '128.4813',
#   '旧': '69.2786',
#   '赖': '30.8978',
#   '靠': '23.9276',
#   '家': '4.89',
#   '据': '4.4661',
#   '稀': '3.8154',
#   '次': '3.6774',
#   '偎': '3.352',
#   '恋': '3.2337',
#   '依': '2.6915',
#   '法': '2.4844'},
#  '侠': {'客': '7.7195', '义': '4.8703', '传': '1.5676'},
#  '侥': {'幸': '2.7112'},
#  '侦': {'探': '51.7494',
#   '缉': '10.204',
#   '察': '3.776',
#   '察术': '3.5196',
#   '探柯南': '1.3507'},
#  '侧': {'面': '4.1999', '脸': '1.3507', '卧': '1.1732'},
#  '侮': {'辱': '6.4083'},
#  '侯': {'德健': '0.1873'},
#  '侵': {'袭': '4.683', '蚀': '4.0027', '犯': '3.7464', '扰': '0.3845'},
#  '便': {'宜': '45.5777',
#   '秘': '16.7306',
#   '捷': '13.7926',
#   '利': '6.8519',
#   '便': '5.0872',
#   '当': '3.8253'},
#  '促': {'销': '51.9072', '进': '27.319', '销价': '16.1883', '成': '1.3507'},
#  '俄': {'罗斯': '17.3911', '国': '3.0661', '语': '0.7789'},
#  '俏': {'皮': '5.4323', '佳人': '4.9886', '媚舞': '1.745'},
#  '俗': {'话': '8.4491',
#   '称': '4.2196',
#   '气': '2.1197',
#   '语': '1.538',
#   '人': '1.1436'},
#  '俘': {'虏': '1.5281'},
#  '保': {'持': '99.2497',
#   '护': '69.4462',
#   '佑': '57.0239',
#   '暖': '51.7691',
#   '证': '42.5116',
#   '湿': '18.9094',
#   '卫': '16.8489',
#   '留': '15.6855',
#   '险': '15.4686',
#   '养': '15.4292',
#   '安': '13.2701',
#   '存': '13.2208',
#   '障': '13.1518',
#   '重': '12.9448',
#   '健': '10.2434',
#   '卫战': '9.0308',
#   '姆': '8.8237',
#   '守': '6.2998',
#   '罗': '5.7872',
#   '镖': '5.0675',
#   '定': '3.983',
#   '鲜': '2.8492',
#   '温': '2.7013',
#   '质期': '2.5239',
#   '住': '2.2774',
#   '管': '2.2774',
#   '养品': '1.3704',
#   '温瓶': '0.5817',
#   '险套': '0.3845'},
#  '信': {'息': '216.1369',
#   '任': '38.8343',
#   '心': '35.1076',
#   '号': '27.9599',
#   '仰': '20.4178',
#   '念': '18.4559',
#   '用卡': '13.2898',
#   '赖': '12.1659',
#   '用': '7.404',
#   '誉': '6.8322',
#   '封': '2.9084',
#   '守': '1.9422',
#   '贷': '1.7647',
#   '息化': '1.7155',
#   '奉': '1.5281',
#   '件': '1.1634',
#   '以为真': '0.5817'},
#  '俨': {'然': '2.3563'},
#  '修': {'复': '199.3275',
#   '身': '42.2454',
#   '炼': '11.9293',
#   '养': '11.3377',
#   '改': '9.5336',
#   '行': '8.7646',
#   '饰': '5.2252',
#   '正': '4.7421',
#   '好': '4.1407',
#   '成': '3.5788',
#   '护': '3.4802',
#   '理': '3.421',
#   '长': '3.3225',
#   '女': '2.1394',
#   '行者': '0.9563',
#   '订': '0.769',
#   '辞': '0.5817',
#   '行路': '0.5817',
#   '为': '0.1873'},
#  '俯': {'卧撑': '2.1591'},
#  '俱': {'乐部': '43.1525'},
#  '俸': {'禄': '48.5453'},
#  '俺': {'们': '9.6815', '家': '4.3576', '娘': '1.1535'},
#  '倍': {'感': '4.8604', '儿': '4.2492', '儿棒': '1.3408', '受': '0.9662'},
#  '倒': {'霉': '37.9075',
#   '入': '29.3007',
#   '数': '19.0869',
#   '计时': '16.908',
#   '下': '10.3321',
#   '计': '7.7097',
#   '流': '4.8604',
#   '头': '3.4703',
#   '退': '2.7408',
#   '闭': '2.7309',
#   '地': '2.7013',
#   '影': '2.445',
#   '掉': '1.9028',
#   '腾': '1.538',
#   '票': '0.5817',
#   '扣': '0.3845'},
#  '倔': {'强': '9.6617'},
#  '倘': {'若': '4.7126'},
#  '候': {'车': '3.7858', '选人': '3.3323', '车室': '3.3225', '机': '3.2337'},
#  '倚': {'天屠龙记': '10.4307'},
#  '倜': {'傥': '1.1732'},
#  '借': {'口': '27.5754',
#   '助': '4.0126',
#   '鉴': '3.3619',
#   '用': '3.0168',
#   '给': '2.8689',
#   '来': '1.7549',
#   '机': '1.1732',
#   '题发挥': '0.1873'},
#  '倡': {'议': '5.1956'},
#  '倩': {'女': '32.8006', '女幽魂': '10.618', '影': '2.0901', '倩': '0.7789'},
#  '债': {'务': '4.5351'},
#  '值': {'得': '149.5498', '班': '30.819', '钱': '8.7941'},
#  '倾': {'听': '18.2686',
#   '诉': '11.5448',
#   '城': '8.3111',
#   '向': '7.0393',
#   '心': '4.4365',
#   '情': '4.19',
#   '斜': '2.6718',
#   '计': '2.6619',
#   '尽': '1.9126',
#   '听者': '0.5817',
#   '泻': '0.5817'},
#  '偃': {'月': '5.5703'},
#  '假': {'期': '106.6044',
#   '如': '30.6218',
#   '装': '30.4739',
#   '日': '21.5023',
#   '象': '3.983',
#   '话': '3.6675',
#   '意': '3.6182',
#   '设': '3.5985',
#   '唱': '3.5591',
#   '冒': '3.283',
#   '发': '3.1056',
#   '证': '2.8985',
#   '假': '2.7506',
#   '面': '2.3366',
#   '牙': '0.7789',
#   '惺惺': '0.769',
#   '扮': '0.5817'},
#  '偏': {'偏': '20.9798',
#   '见': '7.6801',
#   '执': '5.797',
#   '爱': '4.5844',
#   '激': '2.8985',
#   '方': '2.4746',
#   '心': '1.9028',
#   '食': '0.9662',
#   '颇': '0.3845'},
#  '偕': {'老': '4.2985'},
#  '做': {'到': '75.1545',
#   '好': '64.1717',
#   '事': '45.1932',
#   '人': '38.9131',
#   '法': '34.7428',
#   '饭': '28.4331',
#   '出': '25.7022',
#   '完': '20.1023',
#   '主': '17.8643',
#   '梦': '15.1926',
#   '错': '14.4532',
#   '成': '10.9434',
#   '起': '9.0209',
#   '客': '6.497',
#   '做': '5.383',
#   '作': '5.314',
#   '为': '5.1759',
#   '菜': '4.2492',
#   '些': '4.2295',
#   '咩': '3.9238',
#   '爱': '3.4703',
#   '工': '3.3619',
#   '啥': '1.7647',
#   '伴': '1.3704',
#   '么': '0.769'},
#  '停': {'止': '27.6937',
#   '留': '22.0051',
#   '电': '16.6616',
#   '车': '12.856',
#   '机': '10.7068',
#   '下': '9.0505',
#   '车场': '6.6745',
#   '停': '4.5055',
#   '水': '4.3675',
#   '歇': '2.5436',
#   '摆': '1.9619',
#   '售': '1.9225',
#   '运': '1.3605',
#   '放': '1.1634',
#   '雨': '0.9563',
#   '发': '0.3845'},
#  '健': {'康': '356.9024',
#   '健康康': '21.8375',
#   '身': '12.2743',
#   '脾': '4.5548',
#   '身房': '4.2098',
#   '忘': '3.5295',
#   '脑': '3.0858',
#   '全': '2.8887',
#   '身操': '0.769'},
#  '偶': {'尔': '54.3423',
#   '遇': '35.5118',
#   '像': '29.4781',
#   '然': '22.6262',
#   '像剧': '5.5111',
#   '们': '4.2689',
#   '吧': '3.776',
#   '尔幽': '0.1873'},
#  '偷': {'偷': '56.7775',
#   '笑': '28.2852',
#   '拍': '9.3561',
#   '懒': '8.0744',
#   '欢': '5.4421',
#   '走': '4.2492',
#   '着乐': '3.3816',
#   '吃': '3.3816',
#   '情': '2.9478',
#   '心': '1.7549',
#   '工减料': '0.3845'},
#  '偿': {'命': '2.445', '还': '1.9126'},
#  '傍': {'晚': '9.504'},
#  '储': {'存': '3.6281', '蓄': '3.0563'},
#  '催': {'眠': '6.2604',
#   '促': '4.052',
#   '泪': '3.7464',
#   '熟': '2.514',
#   '滴': '0.1873'},
#  '傲': {'慢': '9.3364', '娇': '3.2337', '气': '1.3704'},
#  '傻': {'逼': '39.1695',
#   '瓜': '31.7654',
#   '子': '22.429',
#   '傻': '18.584',
#   '笑': '7.8083',
#   '事': '4.5745',
#   '眼': '2.5535',
#   '仔': '1.3408',
#   '掉': '0.769',
#   '呀': '0.5817',
#   '福': '0.5817'},
#  '像': {'是': '8.7646', '素': '6.7041', '样': '3.0661', '用': '0.5817'},
#  '僧': {'人': '0.7789'},
#  '僵': {'尸': '38.8441', '硬': '4.1013', '尸粉': '2.307'},
#  '儿': {'子': '154.006',
#   '童': '45.7158',
#   '子们': '19.8953',
#   '时': '13.4278',
#   '女': '10.9138',
#   '媳妇': '10.1744',
#   '啊': '4.0027',
#   '们': '3.7562',
#   '去': '1.7253',
#   '科': '1.5478',
#   '孙': '0.7789',
#   '茶素': '0.3845',
#   '郎': '0.1873'},
#  '允': {'许': '35.9554'},
#  '元': {'素': '24.9825',
#   '旦': '18.5348',
#   '月': '16.8785',
#   '宝': '10.5096',
#   '宵': '8.3111',
#   '宵节': '5.1858',
#   '气': '3.4013',
#   '帅': '1.1535',
#   '老': '0.5817'},
#  '兄': {'弟': '157.6736', '弟们': '21.1079', '妹': '4.5351'},
#  '充': {'满': '90.7118',
#   '值卡': '43.8229',
#   '值': '40.5596',
#   '实': '29.5077',
#   '分': '22.1431',
#   '电': '15.6757',
#   '能': '13.7433',
#   '足': '9.5927',
#   '电器': '8.4984',
#   '斥': '5.6787',
#   '沛': '4.2886',
#   '当': '3.3422',
#   '话费': '2.7309',
#   '饥': '1.7549',
#   '其量': '0.976'},
#  '兆': {'头': '4.6731'},
#  '先': {'生': '127.5546',
#   '锋': '15.1433',
#   '进': '9.3265',
#   '后': '5.1069',
#   '走': '4.4759',
#   '得': '3.6084',
#   '机': '2.307',
#   '前': '2.2774',
#   '来': '1.9422',
#   '出': '1.9422',
#   '天': '1.3605',
#   '生们': '1.3605',
#   '用': '1.3507',
#   '别': '0.769',
#   '行版': '0.3845',
#   '传': '0.1873'},
#  '光': {'明': '26.8853',
#   '荣': '19.7375',
#   '芒': '17.3813',
#   '临': '17.0756',
#   '棍': '8.5575',
#   '阴': '7.5223',
#   '滑': '6.4477',
#   '线': '6.3689',
#   '彩': '6.0139',
#   '顾': '5.8858',
#   '泽': '5.7379',
#   '头': '5.4125',
#   '辉': '4.821',
#   '光': '4.2492',
#   '影': '3.4703',
#   '盘': '3.4309',
#   '棍儿': '3.214',
#   '鲜': '3.1351',
#   '亮': '3.1253',
#   '明正大': '2.8887',
#   '环': '2.6619',
#   '明面': '2.1295',
#   '棍节': '1.9521',
#   '网': '1.7549',
#   '大': '1.7253',
#   '纤': '1.3605',
#   '年': '1.1634',
#   '源': '0.769',
#   '束': '0.3845'},
#  '克': {'服': '23.2177',
#   '制': '7.0393',
#   '星': '5.1464',
#   '拉': '3.3915',
#   '斯': '2.8295'},
#  '免': {'费': '198.2134',
#   '疫力': '7.7885',
#   '疫': '6.7534',
#   '得': '4.3576',
#   '税店': '1.745',
#   '不了': '1.5676',
#   '去': '0.769'},
#  '兑': {'换': '15.025', '现': '5.8562'},
#  '兔': {'子': '32.1302', '年': '29.2317', '毛': '3.283', '阿': '1.1436'},
#  '党': {'同伐异': '3.8253', '委': '3.6872', '员': '3.6675'},
#  '兜': {'兜': '5.3238', '里': '4.19', '风': '2.1197'},
#  '入': {'口': '35.8569',
#   '住': '34.3484',
#   '睡': '31.2232',
#   '手': '16.8785',
#   '眠': '10.6871',
#   '学': '9.4054',
#   '座': '8.7744',
#   '场卷': '7.7294',
#   '侵': '6.635',
#   '职': '5.2154',
#   '选': '4.2886',
#   '味': '3.6182',
#   '市': '3.4309',
#   '门': '3.1844',
#   '场': '2.307',
#   '狱': '1.9225',
#   '驻': '1.3704',
#   '夜': '1.3507',
#   '迷': '1.1535',
#   '梦': '1.1535'},
#  '全': {'部': '106.4171',
#   '球': '58.2464',
#   '身': '30.8683',
#   '新': '23.5431',
#   '面': '18.0517',
#   '程': '16.2573',
#   '民': '15.8334',
#   '体': '13.2997',
#   '城': '8.2519',
#   '盛': '8.2026',
#   '集': '7.7885',
#   '力': '7.1181',
#   '方位': '5.452',
#   '心全意': '4.5351',
#   '然': '3.6478',
#   '力以赴': '2.7506',
#   '职': '2.307',
#   '场': '1.5577',
#   '局': '1.5577',
#   '员': '1.538',
#   '称': '0.9563',
#   '军覆没': '0.769',
#   '喷': '0.1873'},
#  '八': {'点': '23.5924',
#   '卦': '17.2728',
#   '十': '12.1856',
#   '戒': '7.9759',
#   '月': '7.6604',
#   '点半': '6.2013',
#   '十年代': '3.2732',
#   '仙过海': '3.1351',
#   '百': '2.8591',
#   '十一': '0.976',
#   '角': '0.9662',
#   '八': '0.5817'},
#  '公': {'司': '258.8851',
#   '园': '64.2702',
#   '主': '62.1604',
#   '路': '45.282',
#   '民': '45.1932',
#   '寓': '40.392',
#   '里': '39.9384',
#   '交': '33.6879',
#   '交车': '32.6231',
#   '平': '29.9415',
#   '布': '28.9852',
#   '开': '26.8655',
#   '益': '23.3952',
#   '共': '18.0418',
#   '车': '17.677',
#   '务员': '15.37',
#   '公': '14.8968',
#   '会': '13.8025',
#   '鸡': '10.4702',
#   '安': '9.1688',
#   '斤': '9.1688',
#   '众': '8.3604',
#   '告': '7.1576',
#   '仔': '7.1181',
#   '正': '6.9308',
#   '安局': '6.7632',
#   '元': '6.2111',
#   '婆': '4.9196',
#   '式': '4.7126',
#   '子': '4.052',
#   '牛': '3.9436',
#   '款': '3.7562',
#   '分': '3.5886',
#   '关': '3.4408',
#   '道': '2.8591',
#   '敌': '2.7408',
#   '认': '2.4647',
#   '测': '2.2873',
#   '馆': '2.1591',
#   '费': '2.0901',
#   '事': '1.7253',
#   '德': '0.769',
#   '职': '0.5817',
#   '休': '0.5817',
#   '愤': '0.3845',
#   '羊': '0.3845',
#   '公公': '0.1873',
#   '租': '0.1873'},
#  '六': {'点': '31.0556',
#   '点半': '8.4491',
#   '月': '6.7829',
#   '十': '5.7477',
#   '六': '4.545',
#   '根清净': '2.7013',
#   '七': '1.9225',
#   '成': '0.5817'},
#  '兰': {'州': '7.69',
#   '花': '4.6041',
#   '蔻': '3.4605',
#   '桂坊': '0.769',
#   '心': '0.1873'},
#  '共': {'同': '57.7141',
#   '度': '8.5674',
#   '鸣': '6.4477',
#   '产党': '5.521',
#   '勉': '4.3576',
#   '和国': '3.9041',
#   '事': '3.7957',
#   '识': '3.4506',
#   '同点': '2.8394',
#   '享': '2.3366',
#   '处': '0.976',
#   '用': '0.5817'},
#  '关': {'注': '476.8459',
#   '系': '152.8624',
#   '于': '115.9408',
#   '心': '90.3273',
#   '键': '63.1069',
#   '怀': '37.1681',
#   '机': '22.0347',
#   '门': '16.908',
#   '键词': '14.0588',
#   '爱': '13.487',
#   '羽': '12.8363',
#   '闭': '12.7081',
#   '照': '6.8717',
#   '掉': '6.4576',
#   '东': '5.2647',
#   '上': '5.1858',
#   '灯': '3.6379',
#   '注点': '3.4408',
#   '节': '3.421',
#   '联': '3.0563',
#   '卡': '2.8591',
#   '切': '2.5535',
#   '山': '2.5337',
#   '火': '2.2774',
#   '系伞': '1.9521'},
#  '兴': {'奋': '98.244',
#   '趣': '50.8818',
#   '隆': '6.7731',
#   '致': '5.0478',
#   '旺': '3.6971',
#   '国': '2.4844',
#   '高采烈': '2.1591'},
#  '兵': {'器': '80.3896', '峰': '5.5111', '力': '4.9492', '刃': '2.1492'},
#  '其': {'实': '502.6664',
#   '他': '125.8293',
#   '中': '75.8545',
#   '它': '20.9502',
#   '余': '7.5421',
#   '次': '6.4379',
#   '间': '2.0802',
#   '乐无穷': '1.1535',
#   '乐': '0.976',
#   '一': '0.9563'},
#  '具': {'有': '44.02', '体': '19.9446', '备': '10.7856'},
#  '典': {'礼': '13.3785',
#   '型': '11.5349',
#   '韦': '5.2647',
#   '故': '1.1535',
#   '当': '0.7789'},
#  '养': {'生': '20.8122',
#   '父': '20.3094',
#   '成': '14.4926',
#   '颜': '9.1491',
#   '老金': '5.2154',
#   '老': '3.7661',
#   '活': '3.2633',
#   '好': '3.2633',
#   '心': '2.7309',
#   '生堂': '2.7013',
#   '护': '2.4844',
#   '胃': '2.1197',
#   '家': '1.5478',
#   '分': '1.5281',
#   '狗': '1.3507',
#   '病': '1.1436'},
#  '兼': {'职': '7.9759',
#   '具': '3.0365',
#   '容': '2.1197',
#   '得': '1.9225',
#   '备': '1.3704',
#   '并': '0.3845'},
#  '冀': {'州': '1.3704'},
#  '内': {'容': '160.6017',
#   '心': '127.1898',
#   '涵': '20.0629',
#   '地': '18.6925',
#   '裤': '14.9954',
#   '衣': '14.5715',
#   '部': '13.3095',
#   '置': '10.0068',
#   '线': '8.9223',
#   '疚': '8.5082',
#   '在': '7.2857',
#   '外': '4.4267',
#   '存': '4.2492',
#   '伤': '3.8943',
#   '幕': '3.8746',
#   '蒙古': '3.8253',
#   '敛': '3.6478',
#   '脏': '2.8591',
#   '侧': '2.7211',
#   '向': '2.7112',
#   '放': '1.5577',
#   '江': '0.976',
#   '战': '0.976',
#   '啡肽': '0.5817'},
#  '再': {'次': '79.3248',
#   '见': '41.1807',
#   '度': '17.2334',
#   '说': '4.7914',
#   '生': '3.6675',
#   '厉': '2.4549',
#   '现': '1.538',
#   '励': '0.9662',
#   '见咯': '0.3845',
#   '宅': '0.1873'},
#  '冒': {'险': '27.8021',
#   '出': '5.8858',
#   '泡': '5.7182',
#   '雨': '4.4957',
#   '充': '3.9436',
#   '烟': '3.0957',
#   '犯': '1.9422'},
#  '写': {'真': '35.7188',
#   '下': '14.0785',
#   '完': '10.1448',
#   '给': '9.1096',
#   '作': '6.635',
#   '出': '4.7421',
#   '到': '4.1309',
#   '写': '2.9478',
#   '道': '2.8492',
#   '信': '2.7309',
#   '成': '2.4844',
#   '字楼': '1.7352'},
#  '军': {'团': '14.463',
#   '事': '8.9815',
#   '人': '4.2788',
#   '队': '4.19',
#   '训': '3.5788',
#   '情': '3.2929',
#   '营': '3.145',
#   '校': '3.0267',
#   '医': '1.538',
#   '官': '1.1732',
#   '区': '1.1535',
#   '火': '0.5817',
#   '中': '0.3845',
#   '功章': '0.1873'},
#  '农': {'历': '29.3598',
#   '村': '23.06',
#   '民': '17.2925',
#   '民工': '15.8236',
#   '场': '12.4617',
#   '业': '6.5562',
#   '夫': '5.4027',
#   '药': '5.0182',
#   '家': '4.7914',
#   '业部': '0.9662',
#   '妇': '0.9563'},
#  '冠': {'军': '72.6898', '以': '0.5817'},
#  '冤': {'家': '8.1237', '枉': '5.1464'},
#  '冥': {'冥': '8.2322', '想': '2.1591'},
#  '冬': {'天': '117.6957',
#   '季': '48.3678',
#   '装': '34.516',
#   '日': '31.4499',
#   '瓜': '9.5434',
#   '眠': '7.7097',
#   '风': '3.4309',
#   '夜': '2.8098',
#   '菇': '1.7352',
#   '至': '1.7253',
#   '雪': '1.3704',
#   '泳': '1.3507'},
#  '冯': {'绍峰': '25.4853',
#   '天贵': '20.0629',
#   '巩': '4.6633',
#   '小刚': '1.9225',
#   '天贵租': '1.1634'},
#  '冰': {'箱': '25.1304',
#   '山': '18.1601',
#   '冷': '16.2278',
#   '淇淋': '12.0476',
#   '糖': '10.4899',
#   '雪': '8.8829',
#   '凉': '6.6843',
#   '激凌': '5.8168',
#   '块': '4.5154',
#   '冰': '4.4464',
#   '冻': '3.9337',
#   '动': '3.0957',
#   '封': '2.3168',
#   '水': '2.2774',
#   '川': '2.1591',
#   '天': '1.9028',
#   '盘龙': '1.5676',
#   '镇': '1.5281',
#   '棍儿': '0.3845'},
#  '冲': {'动': '93.3935',
#   '出': '11.5645',
#   '突': '10.6575',
#   '击': '7.7787',
#   '凉': '7.4533',
#   '上': '6.6942',
#   '锋陷阵': '5.7675',
#   '洗': '5.2942',
#   '刺': '4.3478',
#   '到': '3.6577',
#   '淡': '3.4605',
#   '天': '3.3619',
#   '进': '3.283',
#   '着': '3.2041',
#   '冲': '2.8788',
#   '泡': '2.445',
#   '刷': '1.7352',
#   '劲': '1.7352',
#   '浪': '1.5676',
#   '澡': '0.3845'},
#  '决': {'定': '190.1094',
#   '心': '24.1149',
#   '战': '20.6248',
#   '赛': '19.9939',
#   '策': '6.1914',
#   '斗': '5.9351',
#   '绝': '4.1112'},
#  '况': {'且': '5.7773'},
#  '冷': {'漠': '26.0571',
#   '静': '24.0656',
#   '清': '16.908',
#   '暖': '16.3559',
#   '冷': '14.2658',
#   '啊': '8.5378',
#   '水': '7.6505',
#   '淡': '7.1083',
#   '血': '6.9998',
#   '天': '6.428',
#   '得': '6.3393',
#   '落': '6.2111',
#   '笑话': '6.1618',
#   '战': '5.8661',
#   '汗': '5.7182',
#   '冷清清': '5.6097',
#   '酷': '5.5506',
#   '死': '5.4717',
#   '空气': '5.4125',
#   '风': '5.2055',
#   '笑': '4.9492',
#   '冻': '4.4464',
#   '却': '4.1605',
#   '藏': '3.7661',
#   '冷冷': '3.6971',
#   '阿': '2.6422',
#   '雨': '2.4943',
#   '面': '2.3168',
#   '酷无情': '2.2971',
#   '艳': '1.7352',
#   '吖': '1.3507',
#   '么': '1.1535',
#   '啊啊': '0.3845',
#   '水泡': '0.3845',
#   '烫': '0.1873'},
#  '冻': {'手冻脚': '31.7358',
#   '死': '20.191',
#   '到': '5.7773',
#   '得': '5.3238',
#   '疮': '4.6928',
#   '僵': '3.6379',
#   '吖': '1.7647',
#   '雨': '1.5676',
#   '亲': '0.3845'},
#  '净': {'化': '4.2098', '土': '2.4647', '化器': '2.1098'},
#  '凄': {'凉': '11.811', '美': '3.5393', '惨': '3.0957', '艳': '2.0901'},
#  '准': {'备': '332.6495',
#   '时': '22.853',
#   '确': '10.3124',
#   '则': '3.2239',
#   '点': '3.0464',
#   '许': '1.9225',
#   '入': '0.5817'},
#  '凉': {'水': '4.8703', '拌': '4.4168', '亭': '0.3845'},
#  '凋': {'零': '3.3619', '谢': '2.3563'},
#  '凌': {'晨': '93.3442', '辱': '60.4055', '乱': '13.8419', '波': '0.9563'},
#  '减': {'肥': '94.5667',
#   '少': '37.1287',
#   '轻': '10.3026',
#   '压': '4.3478',
#   '到': '2.1591',
#   '肥法': '2.1197',
#   '弱': '1.9422',
#   '肥药': '1.9422',
#   '速': '1.9422',
#   '肥么': '0.1873'},
#  '凑': {'合': '7.0688', '热闹': '3.6971'},
#  '凛': {'冽': '1.9323'},
#  '凝': {'视': '4.9492', '固': '4.259', '聚': '3.2633', '望': '2.8985'},
#  '几': {'乎': '58.4436',
#   '十': '34.5752',
#   '百': '13.1124',
#   '千': '5.8956',
#   '率': '5.2154',
#   '时': '5.0478',
#   '号': '4.0422',
#   '个': '3.8351',
#   '万': '2.9281',
#   '天': '2.5535',
#   '样': '1.5676',
#   '分': '0.9563'},
#  '凡': {'是': '7.5519', '事': '6.7041', '客': '0.976', '夫俗子': '0.3845'},
#  '凤': {'凰': '21.0586',
#   '姐': '7.1477',
#   '凰网': '3.2436',
#   '爪': '2.7408',
#   '舞鸾': '1.9126'},
#  '凭': {'借': '5.5801', '着': '0.7789'},
#  '凯': {'旋': '42.1961', '撒': '7.5026', '尔特人': '6.9801', '尔': '6.4379'},
#  '凳': {'子': '4.6435'},
#  '凶': {'手': '5.7379', '残': '4.0422', '狠': '2.938', '光': '0.9563'},
#  '凸': {'显': '3.1351'},
#  '凹': {'凸': '2.8394'},
#  '出': {'来': '529.9559',
#   '去': '257.9288',
#   '现': '175.1731',
#   '门': '169.0705',
#   '发': '155.7708',
#   '生': '35.1273',
#   '租车': '28.4134',
#   '色': '27.8514',
#   '口': '24.2529',
#   '行': '19.4319',
#   '乎': '17.0066',
#   '差': '15.1926',
#   '炉': '14.2461',
#   '国': '12.018',
#   '场': '11.6927',
#   '息': '10.8448',
#   '售': '10.5885',
#   '手': '10.3321',
#   '入': '10.0364',
#   '席': '9.9871',
#   '名': '9.011',
#   '租': '8.2125',
#   '血': '8.1139',
#   '汗': '7.9561',
#   '事': '7.69',
#   '版': '7.6012',
#   '街': '7.4829',
#   '于': '7.266',
#   '动': '7.0886',
#   '卖': '6.9604',
#   '品': '6.9407',
#   '轨': '6.9012',
#   '自': '6.7632',
#   '游': '6.6153',
#   '演': '6.5858',
#   '敢性': '6.0632',
#   '院': '5.728',
#   '路': '5.7182',
#   '面': '5.4224',
#   '发咯': '5.2548',
#   '头': '5.1365',
#   '台': '5.0379',
#   '身': '4.9196',
#   '处': '4.6731',
#   '奇': '4.6633',
#   '嫁': '4.5548',
#   '没': '4.5154',
#   '错': '4.4957',
#   '声': '4.4562',
#   '道': '4.1309',
#   '世': '4.1013',
#   '师': '3.8943',
#   '人意料': '3.7562',
#   '局': '3.7562',
#   '海': '3.6675',
#   '众': '3.421',
#   '乎意料': '3.4013',
#   '家': '2.8887',
#   '锅': '2.8689',
#   '彩': '2.8591',
#   '版社': '2.7408',
#   '示': '2.4549',
#   '走': '2.2971',
#   '力': '2.0802',
#   '牌': '1.7253',
#   '货': '1.7253',
#   '城': '1.5577',
#   '境': '1.5281',
#   '山': '1.3605',
#   '航': '1.3408',
#   '水': '1.1732',
#   '糗': '1.1535',
#   '丑': '0.976',
#   '资': '0.9662',
#   '气筒': '0.7789',
#   '远门': '0.769',
#   '风头': '0.769',
#   '窍': '0.5817',
#   '来了': '0.5817',
#   '访': '0.3845',
#   '去蒲': '0.3845'},
#  '击': {'败': '23.3459', '中': '2.8689', '破': '2.2873', '倒': '1.5478'},
#  '函': {'数': '3.0563'},
#  '刀': {'尖': '40.0666',
#   '剑': '8.8434',
#   '子': '3.3126',
#   '枪不入': '1.3704',
#   '工': '0.1873'},
#  '分': {'享': '2191.557',
#   '钟': '296.7828',
#   '手': '91.9935',
#   '析': '82.9825',
#   '享自': '60.6224',
#   '担': '48.3974',
#   '开': '34.8414',
#   '别': '34.7724',
#   '离': '15.5179',
#   '子': '11.7222',
#   '泌': '9.6815',
#   '数': '9.6617',
#   '宝': '8.0153',
#   '裂': '7.759',
#   '明': '7.3745',
#   '配': '7.3252',
#   '解': '6.2801',
#   '类': '6.1618',
#   '为': '5.9646',
#   '公司': '4.5844',
#   '成': '4.2689',
#   '布图': '4.2196',
#   '组': '4.121',
#   '享扮': '4.1112',
#   '辨': '4.0914',
#   '量': '3.8154',
# ...
#   '陀佛': '0.3845'},
#  '弦': {'子': '3.6379'},
#  '弯': {'曲': '6.2801', '腰': '2.7506', '弯': '2.2774', '梳': '0.1873'},
#  '弱': {'爆': '10.8152',
#   '智': '7.6407',
#   '点': '6.8224',
#   '弱': '5.383',
#   '势': '4.0717',
#   '者': '4.0027'},
#  '弹': {'性': '15.3799',
#   '力': '11.2589',
#   '弹堂微博版': '5.7773',
#   '琴': '3.7168',
#   '出': '2.9971',
#   '奏': '1.7253',
#   '幕': '0.7789',
#   '指一挥': '0.769',
#   '药': '0.5817'},
#  '强': {'大': '68.0462',
#   '奸': '62.2393',
#   '烈': '49.5213',
#   '化': '33.9541',
#   '盗': '26.2641',
#   '调': '21.2952',
#   '求': '14.6602',
#   '迫': '11.9293',
#   '势': '11.8011',
#   '迫症': '10.8645',
#   '者': '10.7462',
#   '悍': '9.5829',
#   '于': '8.528',
#   '力': '6.6843',
#   '壮': '4.8999',
#   '度': '4.8407',
#   '行': '4.0126',
#   '人': '3.9534',
#   '制': '3.8055',
#   '劲': '3.7464',
#   '硬': '2.5337',
#   '健': '2.1492'},
#  '归': {'来': '28.0387',
#   '家': '9.1688',
#   '宿': '7.2956',
#   '途': '4.5548',
#   '心似箭': '3.1154',
#   '于': '2.9182',
#   '属感': '2.8492',
#   '去': '1.3507',
#   '纳': '1.1634',
#   '属于': '0.7789'},
#  '当': {'然': '92.6146',
#   '时': '73.6559',
#   '年': '62.6238',
#   '初': '52.1931',
#   '前': '26.2247',
#   '成': '22.2121',
#   '下': '19.6192',
#   '地': '19.1854',
#   '中': '15.4686',
#   '作': '14.0194',
#   '天': '13.4968',
#   '做': '11.9786',
#   '幸': '10.1054',
#   '真': '9.0209',
#   '当': '8.9519',
#   '场': '8.6758',
#   '代': '8.1928',
#   '选': '7.8477',
#   '头': '6.9505',
#   '心': '5.6393',
#   '今': '5.2942',
#   '人': '5.1562',
#   '胸': '4.6928',
#   '面': '4.6633',
#   '官': '4.1506',
#   '兵': '4.0422',
#   '家': '3.983',
#   '事人': '3.983',
#   '日': '3.9534',
#   '晚': '3.7957',
#   '红': '3.6281',
#   '众': '3.5788',
#   '个': '3.0365',
#   '是': '2.9281',
#   '上': '1.7647',
#   '我': '1.7647',
#   '道': '1.7549',
#   '它': '1.5676',
#   '之无愧': '1.3605'},
#  '录': {'制': '18.9291', '音': '5.2548', '像': '4.5943', '取': '2.8591'},
#  '形': {'象': '39.8596',
#   '容': '25.9782',
#   '成': '25.2487',
#   '式': '16.9968',
#   '状': '10.6378',
#   '势': '5.8463',
#   '态': '5.8069',
#   '同': '2.2971',
#   '形色色': '1.9323'},
#  '彩': {'色': '306.8389',
#   '蛋': '63.5604',
#   '排': '29.7246',
#   '虹': '26.1655',
#   '笔': '12.8856',
#   '票': '10.2828',
#   '头': '7.2167',
#   '妆': '5.0083',
#   '信': '2.7112',
#   '铃': '1.5676',
#   '云': '1.3704',
#   '椒': '1.1634',
#   '蝶': '0.5718',
#   '唔': '0.1873'},
#  '彪': {'悍': '6.7928'},
#  '彬': {'彬': '2.7408'},
#  '彭': {'浩翔': '8.2716', '宇': '4.4464'},
#  '彰': {'显': '4.1999'},
#  '影': {'响': '124.035',
#   '响力': '68.2039',
#   '子': '18.0517',
#   '视': '17.1841',
#   '片': '16.3954',
#   '院': '11.3476',
#   '城': '10.5195',
#   '像': '6.4477',
#   '音': '5.3238',
#   '评': '4.4365',
#   '帝': '3.5788',
#   '迷': '1.9126',
#   '视圈': '1.1535',
#   '到': '0.5817'},
#  '彷': {'徨': '6.7435'},
#  '彻': {'底': '71.8222', '夜': '6.3097', '夜未眠': '1.3507'},
#  '彼': {'此': '84.2444', '岸': '7.7984', '得': '1.3704'},
#  '往': {'往': '76.6037',
#   '事': '42.4426',
#   '前': '12.9152',
#   '年': '10.7955',
#   '后': '7.7491',
#   '下': '7.6407',
#   '上': '5.4323',
#   '返': '5.2351',
#   '日': '4.959',
#   '外': '4.6928',
#   '常': '3.8746',
#   '来': '3.845',
#   '回': '2.4647'},
#  '征': {'服': '20.5755',
#   '战': '7.0097',
#   '集': '6.9308',
#   '程': '5.7477',
#   '音': '3.7957',
#   '兆': '3.6675',
#   '婚': '2.9084',
#   '求': '2.307',
#   '询': '1.5577'},
#  '待': {'遇': '11.0913',
#   '会': '7.0984',
#   '人': '6.5069',
#   '续': '3.5788',
#   '会儿': '2.9281',
#   '到': '2.5042',
#   '命': '0.769'},
#  '徇': {'私': '0.1873'},
#  '很': {'多': '449.7044', '少': '6.4083', '爽': '0.5718'},
#  '律': {'师': '12.6194', '师团': '0.1873'},
#  '徐': {'州': '4.9886',
#   '志摩': '4.2689',
#   '家汇': '2.8788',
#   '老太': '2.6718',
#   '汇区': '1.745',
#   '贤': '1.1535'},
#  '徒': {'弟': '5.383', '步': '4.4562', '劳': '3.8253', '然': '0.976'},
#  '得': {'到': '334.71',
#   '意': '34.8315',
#   '瑟': '27.1613',
#   '知': '10.342',
#   '罪': '9.0801',
#   '失': '8.6068',
#   '闲': '8.5773',
#   '分': '8.5181',
#   '以': '7.1674',
#   '出': '6.9505',
#   '来': '6.7731',
#   '奖': '4.0619',
#   '体': '3.5492',
#   '好': '3.2732',
#   '道': '2.3464',
#   '不偿失': '1.5281',
#   '罪人': '1.3507',
#   '手': '1.1535',
#   '势': '0.9662',
#   '寸进尺': '0.1873'},
#  '徘': {'徊': '13.7926'},
#  '御': {'用': '2.4746', '姐': '2.1197'},
#  '循': {'环': '30.5528'},
#  '微': {'博客': '198.9035',
#   '博': '192.1009',
#   '笑': '146.6907',
#   '博特': '73.6559',
#   '博配图': '62.0323',
#   '博无需宅': '62.0224',
#   '博达人': '58.4535',
#   '博拜': '56.9549',
#   '信': '44.1383',
#   '薄': '42.7088',
#   '盘': '41.161',
#   '风': '37.1089',
#   '三国': '33.9245',
#   '群': '25.3177',
#   '博寻龙记': '20.6347',
#   '力': '16.7109',
#   '微': '12.2941',
#   '博控': '11.8406',
#   '波炉': '9.6815',
#   '博登': '8.9618',
#   '博异性': '8.3505',
#   '搏': '8.1829',
#   '软': '8.1336',
#   '博版': '7.2759',
#   '服': '6.9505',
#   '妙': '6.0435',
#   '群群': '5.9942',
#   '号': '5.4027',
#   '分享': '5.3731',
#   '小': '5.0872',
#   '波': '5.0773',
#   '不足道': '4.8999',
#   '博更': '4.5844',
#   '博控们': '3.8943',
#   '博秀': '3.7562',
#   '博里': '3.5492',
#   '弱': '3.2732',
#   '量': '3.1154',
#   '友': '2.8689',
#   '观': '2.6816',
#   '博号': '2.6718',
#   '博庆': '2.0901',
#   '图': '1.9323',
#   '火星': '1.5676',
#   '格': '1.3605',
#   '小说': '1.3408',
#   '博第': '1.1732',
#   '博值': '0.976',
#   '语': '0.9662',
#   '冷': '0.5817',
#   '服饰': '0.3845',
#   '博数': '0.3845',
#   '博者': '0.1873',
#   '茫': '0.1873'},
#  '德': {'克萨斯': '106.7917',
#   '州': '65.5223',
#   '国': '24.3417',
#   '比': '13.1321',
#   '云社': '8.4294',
#   '行': '5.4224',
#   '约科维奇': '3.6971',
#   '语': '2.445',
#   '克士': '1.745',
#   '性': '1.7253',
#   '玛西亚': '0.5718'},
#  '徽': {'章': '29.1922'},
#  '心': {'情': '835.2765',
#   '得': '107.4621',
#   '理': '104.7411',
#   '动': '96.4004',
#   '愿': '90.5245',
#   '想': '60.5436',
#   '灵': '60.4154',
#   '态': '56.738',
#   '里': '50.5368',
#   '心': '48.3777',
#   '疼': '46.4552',
#   '痛': '34.9005',
#   '脏': '26.136',
#   '酸': '24.1346',
#   '底': '23.2966',
#   '计': '22.153',
#   '目': '21.7488',
#   '跳': '21.4037',
#   '爱': '19.3037',
#   '事': '19.0573',
#   '声': '18.1798',
#   '间': '16.2771',
#   '思': '16.0207',
#   '窝': '15.5672',
#   '都': '14.2757',
#   '意': '13.6645',
#   '头': '13.4278',
#   '有': '13.1419',
#   '境': '12.9645',
#   '烦': '12.7081',
#   '碎': '11.5053',
#   '仪': '9.6124',
#   '理学': '8.0449',
#   '扉': '7.6702',
#   '安': '7.2167',
#   '胸': '7.1477',
#   '中': '6.8717',
#   '甘情愿': '6.8618',
#   '语': '6.7632',
#   '机': '6.6153',
#   '血': '6.5463',
#   '眼': '5.452',
#   '地': '5.2844',
#   '脏病': '5.2548',
#   '慌': '5.2055',
#   '智': '5.2055',
#   '存': '5.0675',
#   '软': '5.0379',
#   '魔': '4.683',
#   '生': '4.5252',
#   '寒': '4.0914',
#   '里话': '3.9633',
#   '肝': '3.8055',
#   '满意足': '3.2633',
#   '急': '3.145',
#   '静': '3.076',
#   '形': '3.0365',
#   '口': '3.0168',
#   '理学家': '3.0168',
#   '术': '2.7408',
#   '房': '2.7013',
#   '宽': '2.5337',
#   '绪': '2.5042',
#   '凉': '2.4746',
#   '经': '2.445',
#   '田': '2.3464',
#   '肠': '2.2774',
#   '力': '2.1492',
#   '弦': '2.1197',
#   '不在焉': '2.0999',
#   '悸': '2.0901',
#   '醉': '2.0901',
#   '计生': '1.9323',
#   '灰意冷': '1.7647',
#   '乱': '1.5478',
#   '性': '1.1732',
#   '儿': '1.1634',
#   '志': '1.1634',
#   '旷神怡': '1.1634',
#   '率': '1.1535',
#   '到': '0.9563',
#   '焦': '0.7789',
#   '空': '0.7789',
#   '门': '0.7789',
#   '肌梗塞': '0.5817',
#   '同': '0.3845',
#   '直': '0.3845',
#   '防': '0.1873'},
#  '必': {'须': '209.5019',
#   '要': '52.0649',
#   '备': '23.967',
#   '然': '18.4657',
#   '胜客': '16.4447',
#   '定': '10.9237',
#   '需品': '5.0379',
#   '胜': '4.3774',
#   '需': '3.6577',
#   '不可少': '3.4901',
#   '读': '1.5676',
#   '死': '1.1732',
#   '有路': '0.769'},
#  '忌': {'讳': '1.9422', '睡': '1.9225', '食': '0.7789', '用': '0.5817'},
#  '忍': {'受': '23.3656',
#   '耐': '16.563',
#   '住': '16.0109',
#   '者': '13.8715',
#   '心': '11.3673',
#   '让': '6.3787'},
#  '忏': {'悔': '3.2041'},
#  '忐': {'忑': '15.8236'},
#  '志': {'同道合': '28.0486',
#   '趣': '26.6289',
#   '明': '14.3546',
#   '愿者': '6.6055',
#   '气': '2.514',
#   '愿': '2.2774',
#   '向': '1.5281',
#   '大': '0.7789'},
#  '忘': {'记': '187.7827',
#   '掉': '19.5009',
#   '却': '5.2844',
#   '带': '4.2196',
#   '怀': '3.3619',
#   '形': '3.3027'},
#  '忙': {'碌': '71.7729', '忙': '9.1688', '活': '7.3547', '于': '4.0422'},
#  '忠': {'君': '48.5058',
#   '诚': '14.9264',
#   '告': '6.0731',
#   '实': '5.9252',
#   '孝': '4.1506',
#   '于': '2.4647',
#   '义': '0.5817'},
#  '忧': {'伤': '37.9075',
#   '郁': '13.2701',
#   '愁': '8.4787',
#   '虑': '6.3491',
#   '郁症': '1.7549'},
#  '快': {'乐': '1446.9036',
#   '来': '1231.2991',
#   '快': '214.2933',
#   '捷': '137.1867',
#   '点': '111.1888',
#   '递': '43.5468',
#   '速': '27.0036',
#   '到': '24.4304',
#   '手': '22.8135',
#   '快乐乐': '17.2827',
#   '要': '13.9208',
#   '充': '12.5405',
#   '乐岛': '10.1941',
#   '乐金': '7.5914',
#   '乐哈': '7.1477',
#   '乐哟': '5.8759',
#   '船': '5.7872',
#   '感': '5.6097',
#   '死': '5.0773',
#   '餐': '4.9788',
#   '活': '4.9295',
#   '好': '3.8647',
#   '戳': '3.7661',
#   '刀': '3.5689',
#   '报': '3.5689',
#   '看': '2.3366',
#   '些': '2.3366',
#   '门': '2.0901',
#   '乐咯': '1.9126',
#   '进': '1.9028',
#   '马不停蹄': '1.5577',
#   '乐哦': '1.3704',
#   '车': '0.976',
#   '线': '0.9662',
#   '刀洪吉童': '0.5817',
#   '拍': '0.3845'},
#  '念': {'头': '11.111',
#   '念不忘': '7.1871',
#   '叨': '4.5252',
#   '念': '4.4858',
#   '书': '3.007'},
#  '忽': {'然': '52.5184',
#   '略': '28.7289',
#   '悠': '16.2968',
#   '视': '12.7673',
#   '冷忽热': '3.5492',
#   '然间': '1.7352'},
#  '怀': {'念': '86.9457',
#   '疑': '36.4484',
#   '孕': '21.6009',
#   '旧': '11.8997',
#   '抱': '11.3377',
#   '里': '10.6772',
#   '恋': '2.7013'},
#  '态': {'度': '91.1949', '小度': '28.3049'},
#  '怎': {'么': '1024.3606',
#   '样': '180.4575',
#   '么样': '97.1201',
#   '么回事': '22.153',
#   '么办': '18.1503',
#   '么了': '3.8943'},
#  '怒': {'火': '11.4363',
#   '战': '3.8253',
#   '气': '1.3704',
#   '火中烧': '0.5817',
#   '气冲冲': '0.5817',
#   '形于色': '0.1873'},
#  '怕': {'怕': '6.2703', '事': '0.1873'},
#  '怜': {'悯': '5.1661', '儿': '2.1492'},
#  '思': {'念': '77.4713',
#   '考': '56.2254',
#   '想': '53.4649',
#   '维': '27.3782',
#   '议': '20.1418',
#   '绪': '13.4771',
#   '路': '8.2125',
#   '索': '6.1815',
#   '量': '3.283',
#   '密达': '2.5337',
#   '亲': '2.2971',
#   '绪万千': '1.5577',
#   '想家': '0.769',
#   '域': '0.3845'},
#  '急': {'于': '12.9053',
#   '躁': '4.0224',
#   '死': '3.9929',
#   '性': '3.5591',
#   '着': '3.3816',
#   '切': '3.3619',
#   '诊': '3.3027',
#   '救': '3.2929',
#   '缺': '3.2732',
#   '事': '2.938',
#   '忙': '2.6718',
#   '速': '1.9521',
#   '急忙忙': '1.5577',
#   '急': '1.538',
#   '吼吼': '0.1873'},
#  '性': {'格': '63.0576',
#   '感': '42.8863',
#   '别': '7.4139',
#   '情': '6.7336',
#   '能': '6.4773',
#   '价比': '5.9153',
#   '质': '4.2098',
#   '子': '3.5591',
#   '爱': '2.8788',
#   '生活': '2.0802',
#   '命': '1.7352',
#   '欲': '1.7155',
#   '地': '1.1732',
#   '病': '0.9563'},
#  '怨': {'恨': '5.0971',
#   '言': '3.0168',
#   '念': '2.9971',
#   '气': '1.9323',
#   '天尤人': '1.9028'},
#  '怪': {'谈': '13.5166',
#   '物': '10.342',
#   '兽': '10.2335',
#   '不得': '9.1491',
#   '怪': '7.9759',
#   '人': '7.4139',
#   '异': '3.283',
#   '癖': '2.2971',
#   '客': '2.1197',
#   '事': '1.3408',
#   '兽级': '0.1873'},
#  '总': {'是': '294.6828',
#   '结': '43.3496',
#   '算': '39.4258',
#   '会': '28.8768',
#   '之': '23.6515',
#   '统': '18.8108',
#   '裁': '8.9322',
#   '体': '8.1632',
#   '理': '7.6801',
#   '共': '7.0886',
#   '经理': '5.314',
#   '部': '5.2351',
#   '局': '4.9295',
#   '想': '4.7421',
#   '监': '4.0422',
#   '计': '3.9731',
#   '归': '3.2929',
#   '爱': '2.8591',
#   '能': '2.7309',
#   '站': '2.6718',
#   '额': '2.4746',
#   '数': '2.3366',
#   '和': '1.9521',
#   '有': '1.9422',
#   '要': '1.7352',
#   '导演': '1.7253',
#   '还': '0.9662',
#   '统府': '0.5718'},
#  '恋': {'人': '331.4073',
#   '爱': '149.4907',
#   '情': '14.4827',
#   '上': '5.8661',
#   '恋': '5.0773',
#   '歌': '2.6422',
#   '爱松': '2.6422',
#   '曲': '2.2774',
#   '家': '1.3507',
#   '爱观': '1.3408',
#   '狂': '0.9662',
#   '旧': '0.7789'},
#  '恍': {'惚': '7.0294', '然大悟': '3.3816', '然': '2.7211'},
#  '恐': {'怖': '52.8043',
#   '惧': '26.5106',
#   '龙': '18.1207',
#   '怕': '11.7715',
#   '怖片': '8.0547',
#   '龙园': '7.1674',
#   '惧症': '5.8759',
#   '慌': '5.59',
#   '惧感': '2.0901'},
#  '恒': {'久': '45.2327', '心': '3.421'},
#  '恕': {'不': '2.6718'},
#  '恢': {'复': '41.9595', '恢': '1.7647'},
#  '恨': {'死': '4.545'},
#  '恩': {'爱': '6.5562', '恩': '3.2633', '怨': '2.3366', '赐': '1.7352'},
#  '恭': {'喜发财': '124.6955',
#   '喜': '37.1681',
#   '喜恭喜': '8.4097',
#   '贺': '6.7336',
#   '维': '3.2929',
#   '候': '1.3704'},
#  '恰': {'恰': '5.2154', '好': '3.5295', '似': '1.9323'},
#  '恳': {'求': '1.538'},
#  '恶': {'心': '67.8885',
#   '夜': '26.0571',
#   '劣': '19.708',
#   '梦': '12.9053',
#   '作剧': '12.1363',
#   '魔': '11.7222',
#   '搞': '5.5013',
#   '意': '4.545',
#   '章': '3.9534',
#   '性': '3.4901',
#   '化': '2.8492',
#   '毒': '2.5436',
#   '人': '2.1492',
#   '男': '1.7352',
#   '报': '0.1873'},
#  '恼': {'火': '3.8844', '羞成怒': '0.7789'},
#  '悄': {'悄': '38.4596', '然': '7.5421'},
#  '悉': {'尼': '5.4224'},
#  '悔': {'恨': '4.959'},
#  '悟': {'空': '8.1829'},
#  '悠': {'闲': '11.9096',
#   '悠': '9.0801',
#   '然': '3.421',
#   '久': '2.0999',
#   '扬': '1.9619',
#   '哉': '1.7352'},
#  '患': {'者': '22.084', '得患失': '4.9886', '上': '3.1943', '有': '2.7112'},
#  '您': {'贱': '6.9407', '们': '4.4957', '好': '1.7352'},
#  '悬': {'崖': '89.2626',
#   '剑': '5.6294',
#   '赏': '4.259',
#   '念': '4.2295',
#   '疑': '2.6816',
#   '疑片': '0.1873'},
#  '悲': {'伤': '76.5742',
#   '剧': '60.8295',
#   '催': '44.1088',
#   '哀': '33.6879',
#   '观': '10.2434',
#   '惨': '8.173',
#   '愤': '6.4674',
#   '凉': '3.6872',
#   '情': '3.5295',
#   '痛': '3.0365',
#   '喜': '2.5042',
#   '摧': '2.445',
#   '怆': '1.3408',
#   '从中来': '0.1873'},
#  '悸': {'动': '1.9225'},
#  '悻': {'悻': '0.3845'},
#  '悼': {'念': '1.5577'},
#  '情': {'绪': '111.0705',
#   '况': '103.4003',
#   '侣': '53.948',
#   '人': '52.4987',
#   '人节': '43.3989',
#   '感': '41.9102',
#   '意': '25.2487',
#   '迷': '23.4445',
#   '商': '21.6797',
#   '缘': '20.1418',
#   '谊': '19.5798',
#   '书': '18.5348',
#   '节': '18.1207',
#   '史': '13.4968',
#   '歌': '12.5701',
#   '景': '9.9279',
#   '愿': '9.7012',
#   '调': '9.4251',
#   '怀': '8.4294',
#   '深': '5.9449',
#   '趣': '5.797',
#   '绪化': '5.7576',
#   '话': '5.2449',
#   '结': '4.6731',
#   '冰山': '4.2295',
#   '投': '4.1112',
#   '形': '3.9238',
#   '何': '3.9041',
#   '报': '3.1253',
#   '仇': '3.1154',
#   '愫': '3.0168',
#   '敌': '2.9478',
#   '仁寺': '2.3366',
#   '爱': '2.1591',
#   '真': '1.7253',
#   '妇': '1.3408',
#   '记': '0.3845'},
#  '惆': {'怅': '10.904'},
#  '惊': {'喜': '155.4849',
#   '魂': '47.6777',
#   '心': '28.2754',
#   '醒': '23.9374',
#   '艳': '17.4798',
#   '讶': '15.2517',
#   '人': '10.6969',
#   '奇': '9.4843',
#   '现': '7.9956',
#   '悚': '7.0984',
#   '天': '5.8069',
#   '心动魄': '5.521',
#   '险': '5.1858',
#   '恐': '4.9196',
#   '叹': '3.9436',
#   '吓': '3.5985',
#   '慌': '2.8788',
#   '唿': '2.3267',
#   '蜕': '2.307',
#   '天动地': '2.1394',
#   '呆': '1.7352',
#   '爆': '0.976'},
#  '惜': {'别': '8.4097'},
#  '惟': {'有': '3.4112', '一': '1.538'},
#  '惠': {'州': '8.0054', '普': '2.6422', '民': '0.7789'},
#  '惦': {'念': '17.3911', '记': '8.6561'},
#  '惧': {'怕': '3.8351'},
#  '惨': {'遭': '61.4999',
#   '不忍睹': '4.4661',
#   '烈': '4.2295',
#   '淡': '2.514',
#   '败': '1.7549',
#   '痛': '1.1634',
#   '死': '0.9662',
#   '叫': '0.9563',
#   '无人道': '0.7789',
#   '白': '0.769'},
#  '惩': {'罚': '12.6095'},
#  '惬': {'意': '45.0749'},
#  '惭': {'愧': '7.7097'},
#  '惯': {'性': '3.8055', '犯': '0.1873'},
#  '惰': {'性': '2.1394'},
#  '想': {'要': '216.1763',
#   '到': '205.7555',
#   '起': '177.2829',
#   '想': '99.8116',
#   '念': '60.0802',
#   '法': '59.5577',
#   '象': '53.7508',
#   '来': '28.3444',
#   '吐': '18.101',
#   '像': '13.4968',
#   '死': '12.8462',
#   '去': '12.6983',
#   '好': '12.6391',
#   '家': '12.5701',
#   '见': '11.5546',
#   '睡': '8.3111',
#   '象力': '6.9407',
#   '出': '6.5463',
#   '通': '6.1914',
#   '说': '4.8013',
#   '必': '4.6238',
#   '开': '4.6041',
#   '问': '3.2041',
#   '呕': '2.6915',
#   '来想去': '1.3408',
#   '像力': '0.769'},
#  '惹': {'人': '2.4746', '惹': '1.1732'},
#  '惺': {'惺': '3.8943'},
#  '愈': {'合': '6.2604'},
#  '愉': {'快': '54.1057', '悦': '21.8671'},
#  '意': {'思': '147.095',
#   '义': '75.9235',
#   '见': '70.8067',
#   '外': '51.5325',
#   '识': '38.5188',
#   '味': '32.2288',
#   '大利': '26.7275',
#   '料': '18.4657',
#   '气相投': '13.2701',
#   '志': '12.1955',
#   '想不到': '9.8096',
#   '境': '5.2745',
#   '愿': '4.5252',
#   '盒': '4.0027',
#   '犹未尽': '3.7661',
#   '乱': '2.7112',
#   '大利人': '2.652',
#   '气': '0.9662',
#   '外险': '0.1873'},
#  '愕': {'然': '1.1535'},
#  '愚': {'蠢': '14.8574', '者': '4.0422', '昧': '3.1056', '痴': '0.5817'},
#  '感': {'觉': '717.8569',
#   '谢': '267.2159',
#   '情': '185.0912',
#   '冒': '152.6258',
#   '动': '150.1118',
#   '受': '116.552',
#   '到': '76.1897',
#   '恩': '52.6762',
#   '慨': '42.6694',
#   '人': '26.905',
#   '悟': '25.4261',
#   '激': '24.0853',
#   '叹': '22.3896',
#   '染': '20.9502',
#   '触': '17.5982',
#   '性': '12.4814',
#   '伤': '7.2857',
#   '想': '6.8717',
#   '应': '5.1562',
#   '言': '4.8506',
#   '兴趣': '4.7619',
#   '同身受': '3.5295',
#   '知': '3.4506',
#   '冒药': '3.3225',
#   '脚': '3.007',
#   '慨万千': '2.9478',
#   '化': '1.9619',
#   '官': '1.9323',
#   '染力': '1.3704',
#   '好': '0.3845',
#   '样': '0.3845'},
#  '愣': {'是': '3.6182'},
#  '愤': {'怒': '36.754', '青': '3.1154', '恨': '0.9662'},
#  '愧': {'疚': '6.0731'},
#  '愿': {'意': '135.6093', '望': '101.6947'},
#  '慈': {'善': '9.1392', '悲': '8.3998', '善家': '3.0563', '母': '0.7789'},
#  '慌': {'慌': '17.0461', '乱': '3.7562', '张': '3.7464'},
#  '慎': {'重': '4.6633'},
#  '慢': {'慢': '118.8787', '性': '6.7928'},
#  '慰': {'问': '9.4054', '借': '2.7506', '劳': '1.7155', '问金': '0.9662'},
#  '慵': {'懒': '5.2252'},
#  '慷': {'慨': '5.3731'},
#  ...}

# %% [markdown]
# Results are as expected. Now save the JSON data as multigram.json

# %%
import json

with open('multigram.json', 'w') as outfile:
    json.dump(json_data, outfile)
